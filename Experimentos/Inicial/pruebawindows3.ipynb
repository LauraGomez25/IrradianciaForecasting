# %%
import numpy as np

# %%
# !pip install geopandas
# !pip install pykrige
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Collecting pykrige
#   Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from pykrige) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from pykrige) (1.16.2)
# Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.3 MB/s eta 0:00:00
# Installing collected packages: pykrige
# Successfully installed pykrige-1.7.3

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import tensorflow as tf
from keras import layers, models
from sklearn.pipeline import Pipeline
import pykrige #biblioteca de geoestadística
import pykrige.kriging_tools as kt #herramientas para exportar e importar archivos .asc con biblioteca PyKrige
from pykrige.ok import OrdinaryKriging #Kriging Ordinario con PyKrige

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# forecasting

# %%
path="/content/drive/MyDrive/investigacion/datasetLC"
df=pd.read_csv(path+"/dataset2005-01-09.csv")
df.head()
# Out:
#          lat       lon      band1        band2        band3        band4  \
# 0 -8789850.0  184950.0  2790.0813  4296.806168  2872.552727  2930.404799
# 1 -8784900.0  174600.0  2790.0813  4296.806168  2872.552727  2930.404799
# 2 -8775000.0  169650.0  3114.1877  4332.650201  3231.588515  3286.695698
# 3 -8775000.0  174600.0  2790.0813  4296.806168  2872.552727  2930.404799
# 4 -8775000.0  184950.0  2790.0813  4296.806168  2872.552727  2930.404799
#
#          band5        band6        band7  irradiance
# 0  4249.742666  3006.705973  1823.397754  206.626943
# 1  4249.742666  3006.705973  1823.397754  205.608576
# 2  4235.390294  3102.295887  1894.808666  194.739615
# 3  4249.742666  3006.705973  1823.397754  204.346091
# 4  4249.742666  3006.705973  1823.397754  204.887983

# %%
min_lat=df["lat"].min()
max_lat=df["lat"].max()
min_lon=df["lon"].min()
max_lon=df["lon"].max()
print(min_lat,max_lat,min_lon,max_lon)
# Out:
# -8789850.0 -8554950.0 45000.0 294750.0

# %%
lat=df['lat'].unique()
lon=df['lon'].unique()

lat=np.sort(lat)
lon=np.sort(lon)
dif_lat=np.diff(lat)
dif_lon=np.diff(lon)

min_dif_lat=np.min(dif_lat)
min_dif_lon=np.min(dif_lon)

print(min_dif_lat,min_dif_lon)
# Out:
# 4950.0 4950.0

# %%
def get_images(df,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  matrix_b1 = np.zeros((cols, rows))
  matrix_b2 = np.zeros((cols, rows))
  matrix_b3 = np.zeros((cols, rows))
  matrix_b4 = np.zeros((cols, rows))
  matrix_b5 = np.zeros((cols, rows))
  matrix_b6 = np.zeros((cols, rows))
  matrix_b7 = np.zeros((cols, rows))
  matrix_b8 = np.zeros((cols, rows))
  matrix_irradiance = np.zeros((cols, rows))

  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        matrix_b1[lon_index, lat_index] = row['band1']
        matrix_b2[lon_index, lat_index] = row['band2']
        matrix_b3[lon_index, lat_index] = row['band3']
        matrix_b4[lon_index, lat_index] = row['band4']
        matrix_b5[lon_index, lat_index] = row['band5']
        matrix_b6[lon_index, lat_index] = row['band6']
        matrix_b7[lon_index, lat_index] = row['band7']
        matrix_b8[lon_index, lat_index] = row['irradiance']

        matrix_irradiance[lon_index, lat_index] = row['irradiance']

  satelital_image = np.stack((matrix_b1, matrix_b2, matrix_b3, matrix_b4, matrix_b5, matrix_b6, matrix_b7), axis=-1)
  return satelital_image,matrix_irradiance

def get_dataframe(df,matrix,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  lat=[]
  lon=[]
  irradiance=[]
  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        lat.append(row['lat'])
        lon.append(row['lon'])
        irradiance.append(matrix[lon_index, lat_index])

  df_result=pd.DataFrame({'latitude':lat,'longitude':lon,'irradiance':irradiance})
  return df_result

# %%
satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
satelital_image.shape,matrix_irradiance.shape
# Out:
# ((52, 49, 7), (52, 49))

# %%
#nombre dce columnas
print(df.columns)
# Out:
# Index(['lat', 'lon', 'band1', 'band2', 'band3', 'band4', 'band5', 'band6',
#        'band7', 'irradiance'],
#       dtype='object')

# %%
for i in range(satelital_image.shape[2]):
  plt.title(f"Band {i+1}")
  plt.imshow(satelital_image[:,:,i])
  plt.show()

# %%
X=[]
y=[]
dates=[]
for filename in os.listdir(path):
  print(filename)
  if filename.endswith(".csv"):
    print("read file")
    df=pd.read_csv(path+"/"+filename)
    dates.append(filename.split(".")[0])
    print("get images 2 dataframe")
    satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
    print("append images")
    X.append(satelital_image)
    y.append(matrix_irradiance)
# Out:
# dataset2007-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-03-07.csv
# read file
# ...
# read file
# get images 2 dataframe
# append images
# landsat2014-06-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-06-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-06-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-06-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-20.csv
# read file
# get images 2 dataframe
# append images
# Master
# dataset2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-04.csv
# read file
# get images 2 dataframe
# append images

# %%
df
# Out:
#            lat       lon      band1        band2        band3        band4  \
# 0   -8789850.0  184950.0  1858.1122  4132.022687  2325.464760  2465.765441
# 1   -8784900.0  174600.0  1971.9077  3597.001757  2248.132107  2356.354544
# 2   -8775000.0  169650.0  1903.1478  3897.204968  2320.801086  2426.722917
# 3   -8775000.0  174600.0  1978.6503  3580.397894  2248.132107  2356.354544
# 4   -8775000.0  184950.0  2001.8030  3542.764872  2248.132107  2356.354544
# ..         ...       ...        ...          ...          ...          ...
# 440 -8559900.0  154800.0  2776.5583  4285.591178  2872.552727  2930.404799
# 441 -8559900.0  169650.0  2400.6690  4037.238966  2514.538568  2611.111591
# 442 -8559900.0  174600.0  2282.3840  3801.664932  2376.350065  2507.336480
# 443 -8554950.0  154800.0  2916.9110  4217.998169  3023.498658  3074.688459
# 444 -8554950.0  169650.0  2412.6980  4038.058232  2514.538568  2611.111591
#
#            band5        band6        band7  irradiance
# 0    3975.699130  2908.757556  1732.102615  214.630342
# 1    3852.967634  2862.215809  1721.457722  214.822655
# 2    3947.733366  2900.053869  1725.747886  214.710914
# 3    3852.967634  2862.215809  1721.457722  214.867645
# 4    3852.967634  2862.215809  1721.457722  214.849467
# ..           ...          ...          ...         ...
# 440  4249.742666  3006.705973  1823.397754  231.766402
# 441  4049.468344  2928.249879  1771.278741  238.357094
# 442  3994.738982  2912.450352  1734.711126  240.945771
# 443  4226.428845  3028.295523  1836.341753  228.888384
# 444  4049.468344  2928.249879  1771.278741  238.523794
#
# [445 rows x 10 columns]

# %%
new_dates = []
for date in dates:
  new_dates.append(date.replace("dataset","").replace("landsat", ""))

# %%
#convert str to date
from datetime import datetime
new_dates = [datetime.strptime(date, '%Y-%m-%d') for date in new_dates]

# %%
X=np.array(X)

# %%
y=np.array(y)

# %%
X.shape,y.shape
# Out:
# ((1148, 52, 49, 7), (1148, 52, 49))

# %%
new_dates=np.array(new_dates)
index=np.argsort(new_dates)
X=X[index]
y=y[index]

# %%
#min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)
X.shape
# Out:
# (1148, 52, 49, 7)

# %%
y=scaler.fit_transform(y.reshape(-1, 1)).reshape(y.shape)
y.shape
# Out:
# (1148, 52, 49)

# %%
X.min(),X.max(),y.min(),y.max()
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# windows

# %%
#forecasting window
def window(X,y,v):
  yt=y[v:]
  Xt=[]
  for i in range(X.shape[0]-v):
    Xt.append(X[i:i+v])

  return np.array(Xt),yt

# %%
Xt,yt=window(X,y,3)
Xt.shape,yt.shape
# Out:
# ((1145, 3, 52, 49, 7), (1145, 52, 49))

# %%
Xt.shape[1:]
# Out:
# (3, 52, 49, 7)

# %%
Xt.shape
# Out:
# (1145, 3, 52, 49, 7)

# %%
Xtrain=Xt[:int(0.8*Xt.shape[0])]
ytrain=yt[:int(0.8*yt.shape[0])]

Xtest=Xt[int(0.8*Xt.shape[0]):]
ytest=yt[int(0.8*yt.shape[0]):]

# %%
X_train=Xtrain[:int(0.8*Xtrain.shape[0])]
y_train=ytrain[:int(0.8*ytrain.shape[0])]

X_test=Xtrain[int(0.8*Xtrain.shape[0]):]
y_test=ytrain[int(0.8*ytrain.shape[0]):]

# %% [markdown]
# model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ConvLSTM2D, Conv2D, BatchNormalization, Dropout

inputs = Input(shape=(Xt.shape[1:]))  # ventana temporal, alto, ancho, canales

x = ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False, activation='relu')(inputs)
x = BatchNormalization()(x)             # Normalización para estabilizar
x = Dropout(0.3)(x)                     # Dropout para evitar sobreajuste

x = Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu')(x)
x = BatchNormalization()(x)             # Otra capa de normalización
x = Dropout(0.3)(x)                     # Más dropout

outputs = Conv2D(filters=1, kernel_size=(3, 3), padding='same', activation='linear')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 3, 52, 49, 7)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 52, 49, 32)     │        45,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 52, 49, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 52, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 52, 49, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 52, 49, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 52, 49, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 52, 49, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,017 (195.38 KB)
#  Trainable params: 49,921 (195.00 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
path="/content/drive/MyDrive/investigacion/windows"

# %%
#early stopping
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#metrics
from tensorflow.keras.metrics import MeanAbsoluteError

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-8)
checkpoint= ModelCheckpoint(filepath=path+'model.keras', monitor='val_loss', save_best_only=True)

model.fit(Xtrain, ytrain, epochs=1000, batch_size=32,validation_data=(X_test,y_test), callbacks=[early_stopping, reduce_lr,checkpoint])
# Out:
# Epoch 1/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 296ms/step - loss: 1.4620 - mae: 0.8336 - val_loss: 0.1014 - val_mae: 0.2031 - learning_rate: 0.0010
# Epoch 2/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.5778 - mae: 0.5278 - val_loss: 0.0927 - val_mae: 0.2110 - learning_rate: 0.0010
# Epoch 3/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3637 - mae: 0.4214 - val_loss: 0.0904 - val_mae: 0.1926 - learning_rate: 0.0010
# Epoch 4/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2426 - mae: 0.3471 - val_loss: 0.0896 - val_mae: 0.1780 - learning_rate: 0.0010
# Epoch 5/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1631 - mae: 0.2880 - val_loss: 0.0899 - val_mae: 0.1639 - learning_rate: 0.0010
# Epoch 6/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.1105 - mae: 0.2397 - val_loss: 0.0898 - val_mae: 0.1515 - learning_rate: 0.0010
# Epoch 7/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0759 - mae: 0.1991 - val_loss: 0.0889 - val_mae: 0.1411 - learning_rate: 0.0010
# Epoch 8/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0521 - mae: 0.1648 - val_loss: 0.0876 - val_mae: 0.1398 - learning_rate: 0.0010
# Epoch 9/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0367 - mae: 0.1371 - val_loss: 0.0852 - val_mae: 0.1377 - learning_rate: 0.0010
# Epoch 10/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0269 - mae: 0.1152 - val_loss: 0.0815 - val_mae: 0.1330 - learning_rate: 0.0010
# Epoch 11/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0205 - mae: 0.0976 - val_loss: 0.0759 - val_mae: 0.1269 - learning_rate: 0.0010
# Epoch 12/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0163 - mae: 0.0845 - val_loss: 0.0687 - val_mae: 0.1187 - learning_rate: 0.0010
# Epoch 13/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0142 - mae: 0.0758 - val_loss: 0.0617 - val_mae: 0.1113 - learning_rate: 0.0010
# Epoch 14/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0128 - mae: 0.0698 - val_loss: 0.0542 - val_mae: 0.1041 - learning_rate: 0.0010
# Epoch 15/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0119 - mae: 0.0658 - val_loss: 0.0469 - val_mae: 0.0973 - learning_rate: 0.0010
# Epoch 16/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0113 - mae: 0.0632 - val_loss: 0.0402 - val_mae: 0.0907 - learning_rate: 0.0010
# Epoch 17/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0111 - mae: 0.0615 - val_loss: 0.0332 - val_mae: 0.0832 - learning_rate: 0.0010
# Epoch 18/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0107 - mae: 0.0599 - val_loss: 0.0276 - val_mae: 0.0764 - learning_rate: 0.0010
# Epoch 19/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0103 - mae: 0.0584 - val_loss: 0.0217 - val_mae: 0.0688 - learning_rate: 0.0010
# Epoch 20/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0102 - mae: 0.0575 - val_loss: 0.0170 - val_mae: 0.0622 - learning_rate: 0.0010
# Epoch 21/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0100 - mae: 0.0566 - val_loss: 0.0135 - val_mae: 0.0578 - learning_rate: 0.0010
# Epoch 22/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0096 - mae: 0.0555 - val_loss: 0.0106 - val_mae: 0.0504 - learning_rate: 0.0010
# Epoch 23/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0095 - mae: 0.0549 - val_loss: 0.0088 - val_mae: 0.0465 - learning_rate: 0.0010
# Epoch 24/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0094 - mae: 0.0541 - val_loss: 0.0073 - val_mae: 0.0422 - learning_rate: 0.0010
# Epoch 25/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0094 - mae: 0.0537 - val_loss: 0.0058 - val_mae: 0.0358 - learning_rate: 0.0010
# Epoch 26/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0092 - mae: 0.0531 - val_loss: 0.0052 - val_mae: 0.0317 - learning_rate: 0.0010
# Epoch 27/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0090 - mae: 0.0525 - val_loss: 0.0048 - val_mae: 0.0291 - learning_rate: 0.0010
# Epoch 28/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0089 - mae: 0.0521 - val_loss: 0.0046 - val_mae: 0.0299 - learning_rate: 0.0010
# Epoch 29/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0088 - mae: 0.0516 - val_loss: 0.0043 - val_mae: 0.0258 - learning_rate: 0.0010
# Epoch 30/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0088 - mae: 0.0512 - val_loss: 0.0042 - val_mae: 0.0243 - learning_rate: 0.0010
# Epoch 31/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0087 - mae: 0.0510 - val_loss: 0.0042 - val_mae: 0.0263 - learning_rate: 0.0010
# Epoch 32/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0086 - mae: 0.0507 - val_loss: 0.0040 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 33/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0086 - mae: 0.0505 - val_loss: 0.0039 - val_mae: 0.0218 - learning_rate: 0.0010
# Epoch 34/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0084 - mae: 0.0500 - val_loss: 0.0039 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 35/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0084 - mae: 0.0498 - val_loss: 0.0039 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 36/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0084 - mae: 0.0497 - val_loss: 0.0039 - val_mae: 0.0218 - learning_rate: 0.0010
# Epoch 37/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0082 - mae: 0.0493 - val_loss: 0.0038 - val_mae: 0.0209 - learning_rate: 0.0010
# Epoch 38/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0081 - mae: 0.0490 - val_loss: 0.0037 - val_mae: 0.0203 - learning_rate: 0.0010
# Epoch 39/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0082 - mae: 0.0490 - val_loss: 0.0037 - val_mae: 0.0211 - learning_rate: 0.0010
# Epoch 40/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0081 - mae: 0.0487 - val_loss: 0.0037 - val_mae: 0.0241 - learning_rate: 0.0010
# Epoch 41/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0081 - mae: 0.0489 - val_loss: 0.0036 - val_mae: 0.0204 - learning_rate: 0.0010
# Epoch 42/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0080 - mae: 0.0484 - val_loss: 0.0036 - val_mae: 0.0223 - learning_rate: 0.0010
# Epoch 43/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 0.0078 - mae: 0.0480 - val_loss: 0.0036 - val_mae: 0.0206 - learning_rate: 0.0010
# Epoch 44/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0078 - mae: 0.0479 - val_loss: 0.0036 - val_mae: 0.0212 - learning_rate: 0.0010
# Epoch 45/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0078 - mae: 0.0478 - val_loss: 0.0036 - val_mae: 0.0207 - learning_rate: 0.0010
# Epoch 46/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0078 - mae: 0.0477 - val_loss: 0.0036 - val_mae: 0.0219 - learning_rate: 0.0010
# Epoch 47/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0077 - mae: 0.0475 - val_loss: 0.0035 - val_mae: 0.0209 - learning_rate: 0.0010
# Epoch 48/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0075 - mae: 0.0472 - val_loss: 0.0035 - val_mae: 0.0213 - learning_rate: 0.0010
# Epoch 49/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0075 - mae: 0.0471 - val_loss: 0.0034 - val_mae: 0.0200 - learning_rate: 0.0010
# Epoch 50/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0076 - mae: 0.0469 - val_loss: 0.0034 - val_mae: 0.0208 - learning_rate: 0.0010
# Epoch 51/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0073 - mae: 0.0467 - val_loss: 0.0037 - val_mae: 0.0221 - learning_rate: 0.0010
# Epoch 52/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0075 - mae: 0.0469 - val_loss: 0.0034 - val_mae: 0.0211 - learning_rate: 0.0010
# Epoch 53/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0074 - mae: 0.0465 - val_loss: 0.0034 - val_mae: 0.0210 - learning_rate: 0.0010
# Epoch 54/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0074 - mae: 0.0465 - val_loss: 0.0034 - val_mae: 0.0204 - learning_rate: 0.0010
# Epoch 55/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0072 - mae: 0.0463 - val_loss: 0.0033 - val_mae: 0.0200 - learning_rate: 0.0010
# Epoch 56/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0073 - mae: 0.0461 - val_loss: 0.0033 - val_mae: 0.0209 - learning_rate: 0.0010
# Epoch 57/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0072 - mae: 0.0460 - val_loss: 0.0032 - val_mae: 0.0212 - learning_rate: 0.0010
# Epoch 58/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0072 - mae: 0.0460 - val_loss: 0.0032 - val_mae: 0.0204 - learning_rate: 0.0010
# Epoch 59/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0072 - mae: 0.0460 - val_loss: 0.0034 - val_mae: 0.0218 - learning_rate: 0.0010
# Epoch 60/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0069 - mae: 0.0455 - val_loss: 0.0033 - val_mae: 0.0218 - learning_rate: 0.0010
# Epoch 61/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0070 - mae: 0.0456 - val_loss: 0.0031 - val_mae: 0.0191 - learning_rate: 0.0010
# Epoch 62/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0070 - mae: 0.0454 - val_loss: 0.0032 - val_mae: 0.0207 - learning_rate: 0.0010
# Epoch 63/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0069 - mae: 0.0452 - val_loss: 0.0031 - val_mae: 0.0202 - learning_rate: 0.0010
# Epoch 64/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0070 - mae: 0.0453 - val_loss: 0.0030 - val_mae: 0.0191 - learning_rate: 0.0010
# Epoch 65/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0069 - mae: 0.0449 - val_loss: 0.0030 - val_mae: 0.0197 - learning_rate: 0.0010
# Epoch 66/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0068 - mae: 0.0450 - val_loss: 0.0030 - val_mae: 0.0199 - learning_rate: 0.0010
# Epoch 67/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0068 - mae: 0.0448 - val_loss: 0.0030 - val_mae: 0.0195 - learning_rate: 0.0010
# Epoch 68/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - mae: 0.0445 - val_loss: 0.0030 - val_mae: 0.0197 - learning_rate: 0.0010
# Epoch 69/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0067 - mae: 0.0444 - val_loss: 0.0031 - val_mae: 0.0208 - learning_rate: 0.0010
# Epoch 70/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0067 - mae: 0.0444 - val_loss: 0.0030 - val_mae: 0.0205 - learning_rate: 0.0010
# Epoch 71/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0067 - mae: 0.0443 - val_loss: 0.0028 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 72/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0066 - mae: 0.0441 - val_loss: 0.0028 - val_mae: 0.0193 - learning_rate: 0.0010
# Epoch 73/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0441 - val_loss: 0.0028 - val_mae: 0.0188 - learning_rate: 0.0010
# Epoch 74/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0065 - mae: 0.0439 - val_loss: 0.0027 - val_mae: 0.0185 - learning_rate: 0.0010
# Epoch 75/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0065 - mae: 0.0440 - val_loss: 0.0028 - val_mae: 0.0204 - learning_rate: 0.0010
# Epoch 76/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0065 - mae: 0.0437 - val_loss: 0.0026 - val_mae: 0.0183 - learning_rate: 0.0010
# Epoch 77/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0064 - mae: 0.0435 - val_loss: 0.0029 - val_mae: 0.0198 - learning_rate: 0.0010
# Epoch 78/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0064 - mae: 0.0433 - val_loss: 0.0030 - val_mae: 0.0211 - learning_rate: 0.0010
# Epoch 79/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0065 - mae: 0.0436 - val_loss: 0.0025 - val_mae: 0.0178 - learning_rate: 0.0010
# Epoch 80/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0064 - mae: 0.0433 - val_loss: 0.0027 - val_mae: 0.0206 - learning_rate: 0.0010
# Epoch 81/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0063 - mae: 0.0430 - val_loss: 0.0026 - val_mae: 0.0179 - learning_rate: 0.0010
# Epoch 82/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0063 - mae: 0.0430 - val_loss: 0.0028 - val_mae: 0.0203 - learning_rate: 0.0010
# Epoch 83/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0063 - mae: 0.0430 - val_loss: 0.0026 - val_mae: 0.0180 - learning_rate: 0.0010
# Epoch 84/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0062 - mae: 0.0428 - val_loss: 0.0026 - val_mae: 0.0190 - learning_rate: 0.0010
# Epoch 85/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0062 - mae: 0.0427 - val_loss: 0.0029 - val_mae: 0.0197 - learning_rate: 0.0010
# Epoch 86/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.0062 - mae: 0.0426 - val_loss: 0.0024 - val_mae: 0.0173 - learning_rate: 0.0010
# Epoch 87/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0061 - mae: 0.0423 - val_loss: 0.0025 - val_mae: 0.0172 - learning_rate: 0.0010
# Epoch 88/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0062 - mae: 0.0425 - val_loss: 0.0024 - val_mae: 0.0167 - learning_rate: 0.0010
# Epoch 89/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0061 - mae: 0.0423 - val_loss: 0.0025 - val_mae: 0.0170 - learning_rate: 0.0010
# Epoch 90/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0061 - mae: 0.0422 - val_loss: 0.0024 - val_mae: 0.0164 - learning_rate: 0.0010
# Epoch 91/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0061 - mae: 0.0422 - val_loss: 0.0025 - val_mae: 0.0170 - learning_rate: 0.0010
# Epoch 92/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0061 - mae: 0.0422 - val_loss: 0.0026 - val_mae: 0.0176 - learning_rate: 0.0010
# Epoch 93/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0060 - mae: 0.0420 - val_loss: 0.0023 - val_mae: 0.0170 - learning_rate: 0.0010
# Epoch 94/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0061 - mae: 0.0421 - val_loss: 0.0023 - val_mae: 0.0163 - learning_rate: 0.0010
# Epoch 95/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0060 - mae: 0.0418 - val_loss: 0.0025 - val_mae: 0.0184 - learning_rate: 0.0010
# Epoch 96/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0060 - mae: 0.0418 - val_loss: 0.0024 - val_mae: 0.0166 - learning_rate: 0.0010
# Epoch 97/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0059 - mae: 0.0417 - val_loss: 0.0025 - val_mae: 0.0182 - learning_rate: 0.0010
# Epoch 98/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0060 - mae: 0.0416 - val_loss: 0.0024 - val_mae: 0.0172 - learning_rate: 0.0010
# Epoch 99/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0060 - mae: 0.0415 - val_loss: 0.0022 - val_mae: 0.0156 - learning_rate: 0.0010
# Epoch 100/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0059 - mae: 0.0414 - val_loss: 0.0023 - val_mae: 0.0166 - learning_rate: 0.0010
# Epoch 101/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0060 - mae: 0.0416 - val_loss: 0.0024 - val_mae: 0.0192 - learning_rate: 0.0010
# Epoch 102/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0059 - mae: 0.0415 - val_loss: 0.0024 - val_mae: 0.0162 - learning_rate: 0.0010
# Epoch 103/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0059 - mae: 0.0412 - val_loss: 0.0022 - val_mae: 0.0153 - learning_rate: 0.0010
# Epoch 104/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0059 - mae: 0.0412 - val_loss: 0.0024 - val_mae: 0.0169 - learning_rate: 0.0010
# Epoch 105/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0059 - mae: 0.0411 - val_loss: 0.0022 - val_mae: 0.0170 - learning_rate: 0.0010
# Epoch 106/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0059 - mae: 0.0412 - val_loss: 0.0023 - val_mae: 0.0157 - learning_rate: 0.0010
# Epoch 107/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0059 - mae: 0.0410 - val_loss: 0.0022 - val_mae: 0.0161 - learning_rate: 0.0010
# Epoch 108/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0058 - mae: 0.0409 - val_loss: 0.0026 - val_mae: 0.0205 - learning_rate: 0.0010
# Epoch 109/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0058 - mae: 0.0409 - val_loss: 0.0022 - val_mae: 0.0157 - learning_rate: 0.0010
# Epoch 110/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0057 - mae: 0.0408 - val_loss: 0.0021 - val_mae: 0.0154 - learning_rate: 0.0010
# Epoch 111/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0058 - mae: 0.0408 - val_loss: 0.0023 - val_mae: 0.0162 - learning_rate: 0.0010
# Epoch 112/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0058 - mae: 0.0407 - val_loss: 0.0024 - val_mae: 0.0163 - learning_rate: 0.0010
# Epoch 113/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0058 - mae: 0.0406 - val_loss: 0.0023 - val_mae: 0.0171 - learning_rate: 0.0010
# Epoch 114/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0057 - mae: 0.0405 - val_loss: 0.0022 - val_mae: 0.0154 - learning_rate: 1.0000e-04
# Epoch 115/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0058 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0151 - learning_rate: 1.0000e-04
# Epoch 116/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0152 - learning_rate: 1.0000e-04
# Epoch 117/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0153 - learning_rate: 1.0000e-04
# Epoch 118/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0058 - mae: 0.0405 - val_loss: 0.0022 - val_mae: 0.0148 - learning_rate: 1.0000e-04
# Epoch 119/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0057 - mae: 0.0403 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-04
# Epoch 120/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0152 - learning_rate: 1.0000e-04
# Epoch 121/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0058 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0149 - learning_rate: 1.0000e-04
# Epoch 122/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0057 - mae: 0.0403 - val_loss: 0.0022 - val_mae: 0.0152 - learning_rate: 1.0000e-04
# Epoch 123/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0057 - mae: 0.0403 - val_loss: 0.0022 - val_mae: 0.0148 - learning_rate: 1.0000e-04
# Epoch 124/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0056 - mae: 0.0403 - val_loss: 0.0022 - val_mae: 0.0149 - learning_rate: 1.0000e-05
# Epoch 125/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-05
# Epoch 126/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-05
# Epoch 127/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0058 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-05
# Epoch 128/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-05
# Epoch 129/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0057 - mae: 0.0403 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-05
# Epoch 130/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0022 - val_mae: 0.0150 - learning_rate: 1.0000e-05

# %%
#plot history
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
model.evaluate(Xtest,ytest)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.0025 - mae: 0.0159
# [0.0023898440413177013, 0.01574300229549408]

# %%
ytest.shape
# Out:
# (229, 52, 49)

# %%
#r2 score
from sklearn.metrics import r2_score
n=ytest.shape[0]
y_pred = model.predict(Xtest)
y_pred[ytest==0]=0
r2_score(ytest.reshape(n,-1), y_pred.reshape(n,-1))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 0.7319986910500852

# %%
plt.subplot(1, 2, 1)
plt.title('Original')
plt.imshow(ytest[90])
plt.subplot(1, 2, 2)
plt.title('Predicted')
plt.imshow(y_pred[90])
plt.show()
