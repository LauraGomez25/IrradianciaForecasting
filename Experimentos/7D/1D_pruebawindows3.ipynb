# %%
import numpy as np

# %%
# !pip install geopandas
# !pip install pykrige
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Collecting pykrige
#   Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from pykrige) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from pykrige) (1.16.2)
# Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.1 MB/s eta 0:00:00
# Installing collected packages: pykrige
# Successfully installed pykrige-1.7.3

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import tensorflow as tf
from keras import layers, models
from sklearn.pipeline import Pipeline
import pykrige #biblioteca de geoestadística
import pykrige.kriging_tools as kt #herramientas para exportar e importar archivos .asc con biblioteca PyKrige
from pykrige.ok import OrdinaryKriging #Kriging Ordinario con PyKrige

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# forecasting

# %%
path="/content/drive/MyDrive/investigacion/1D/datasetLCprueba2"
df=pd.read_csv(path+"/dataset2005-01-09.csv")
df.head()
# Out:
#          lat       lon     band1     band2     band3     band4     band5  \
# 0 -8789850.0  184950.0  0.105978  0.099330  0.069518  0.362668  0.197366
# 1 -8784900.0  174600.0  0.105689  0.095687  0.070707  0.330275  0.167146
# 2 -8775000.0  164700.0  0.105804  0.090551  0.068804  0.302913  0.142175
# 3 -8775000.0  169650.0  0.106262  0.085919  0.059622  0.293441  0.117007
# 4 -8775000.0  174600.0  0.106714  0.090143  0.063222  0.305589  0.153831
#
#         band6     band7  irradiance
# 0  296.785832  0.075079  205.371589
# 1  293.817967  0.068660  210.671487
# 2  292.549939  0.057090  208.897715
# 3  293.856536  0.042214  200.784402
# 4  294.796857  0.061334  202.307685

# %%
min_lat=df["lat"].min()
max_lat=df["lat"].max()
min_lon=df["lon"].min()
max_lon=df["lon"].max()
print(min_lat,max_lat,min_lon,max_lon)
# Out:
# -8789850.0 -8554950.0 45000.0 294750.0

# %%
lat=df['lat'].unique()
lon=df['lon'].unique()

lat=np.sort(lat)
lon=np.sort(lon)
dif_lat=np.diff(lat)
dif_lon=np.diff(lon)

min_dif_lat=np.min(dif_lat)
min_dif_lon=np.min(dif_lon)

print(min_dif_lat,min_dif_lon)
# Out:
# 4950.0 4950.0

# %%
def get_images(df,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  matrix_b1 = np.zeros((cols, rows))
  matrix_b2 = np.zeros((cols, rows))
  matrix_b3 = np.zeros((cols, rows))
  matrix_b4 = np.zeros((cols, rows))
  matrix_b5 = np.zeros((cols, rows))
  matrix_b6 = np.zeros((cols, rows))
  matrix_b7 = np.zeros((cols, rows))
  matrix_b8 = np.zeros((cols, rows))
  matrix_irradiance = np.zeros((cols, rows))

  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        matrix_b1[lon_index, lat_index] = row['band1']
        matrix_b2[lon_index, lat_index] = row['band2']
        matrix_b3[lon_index, lat_index] = row['band3']
        matrix_b4[lon_index, lat_index] = row['band4']
        matrix_b5[lon_index, lat_index] = row['band5']
        matrix_b6[lon_index, lat_index] = row['band6']
        matrix_b7[lon_index, lat_index] = row['band7']
        matrix_b8[lon_index, lat_index] = row['irradiance']

        matrix_irradiance[lon_index, lat_index] = row['irradiance']

  satelital_image = np.stack((matrix_b1, matrix_b2, matrix_b3, matrix_b4, matrix_b5, matrix_b6, matrix_b7), axis=-1)
  return satelital_image,matrix_irradiance

def get_dataframe(df,matrix,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  lat=[]
  lon=[]
  irradiance=[]
  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        lat.append(row['lat'])
        lon.append(row['lon'])
        irradiance.append(matrix[lon_index, lat_index])

  df_result=pd.DataFrame({'latitude':lat,'longitude':lon,'irradiance':irradiance})
  return df_result

# %%
satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
satelital_image.shape,matrix_irradiance.shape
# Out:
# ((52, 49, 7), (52, 49))

# %%
#nombre dce columnas
print(df.columns)
# Out:
# Index(['lat', 'lon', 'band1', 'band2', 'band3', 'band4', 'band5', 'band6',
#        'band7', 'irradiance'],
#       dtype='object')

# %%
for i in range(satelital_image.shape[2]):
  plt.title(f"Band {i+1}")
  plt.imshow(satelital_image[:,:,i])
  plt.show()

# %%
X=[]
y=[]
dates=[]
for filename in os.listdir(path):
  print(filename)
  if filename.endswith(".csv"):
    print("read file")
    df=pd.read_csv(path+"/"+filename)
    dates.append(filename.split(".")[0])
    print("get images 2 dataframe")
    satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
    print("append images")
    X.append(satelital_image)
    y.append(matrix_irradiance)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# read file
# get images 2 dataframe
# append images
# dataset2006-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-07.csv
# read file
# get images 2 dataframe
# append images
# ...
# read file
# get images 2 dataframe
# append images
# dataset2003-06-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-19.csv
# read file
# get images 2 dataframe
# append images
# master
# landsat2005-01-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-08.csv
# read file
# get images 2 dataframe
# append images

# %%
df
# Out:
#            lat       lon     band1     band2     band3     band4     band5  \
# 0   -8789850.0  184950.0  0.104884  0.093748  0.071923  0.323682  0.161516
# 1   -8784900.0  174600.0  0.105010  0.089144  0.066448  0.299801  0.150575
# 2   -8775000.0  164700.0  0.105368  0.098525  0.073428  0.346393  0.164950
# 3   -8775000.0  169650.0  0.105539  0.090225  0.066063  0.305286  0.152042
# 4   -8775000.0  174600.0  0.105682  0.084698  0.050833  0.313825  0.142911
# ..         ...       ...       ...       ...       ...       ...       ...
# 429 -8559900.0  154800.0  0.097840  0.087566  0.056465  0.344339  0.167057
# 430 -8559900.0  169650.0  0.097643  0.082281  0.054293  0.298851  0.136582
# 431 -8559900.0  174600.0  0.097733  0.081179  0.049978  0.302043  0.131996
# 432 -8554950.0  154800.0  0.097920  0.091565  0.070670  0.321751  0.160603
# 433 -8554950.0  169650.0  0.097599  0.084908  0.062493  0.296173  0.163264
#
#           band6     band7  irradiance
# 0    292.011622  0.075456  212.859576
# 1    293.689880  0.062085  207.421066
# 2    292.243810  0.072669  211.965826
# 3    294.033563  0.060793  205.371173
# 4    296.525525  0.044172  201.731474
# ..          ...       ...         ...
# 429  296.206479  0.060925  214.413316
# 430  295.434918  0.048005  216.818518
# 431  296.337935  0.042086  214.708635
# 432  292.894248  0.070693  218.903434
# 433  295.925340  0.069019  233.160675
#
# [434 rows x 10 columns]

# %%
new_dates = []
for date in dates:
  new_dates.append(date.replace("dataset","").replace("landsat", ""))

# %%
#convert str to date
from datetime import datetime
new_dates = [datetime.strptime(date, '%Y-%m-%d') for date in new_dates]

# %%
X=np.array(X)

# %%
y=np.array(y)

# %%
X.shape,y.shape
# Out:
# ((5009, 52, 49, 7), (5009, 52, 49))

# %%
new_dates=np.array(new_dates)
index=np.argsort(new_dates)
X=X[index]
y=y[index]

# %%
#min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)
X.shape
# Out:
# (5009, 52, 49, 7)

# %%
y=scaler.fit_transform(y.reshape(-1, 1)).reshape(y.shape)
y.shape
# Out:
# (5009, 52, 49)

# %%
X.min(),X.max(),y.min(),y.max()
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# windows

# %%
#forecasting window
def window(X,y,v):
  yt=y[v:]
  Xt=[]
  for i in range(X.shape[0]-v):
    Xt.append(X[i:i+v])

  return np.array(Xt),yt

# %%
Xt,yt=window(X,y,3)
Xt.shape,yt.shape
# Out:
# ((5006, 3, 52, 49, 7), (5006, 52, 49))

# %%
Xt.shape[1:]
# Out:
# (3, 52, 49, 7)

# %%
Xt.shape
# Out:
# (5006, 3, 52, 49, 7)

# %%
Xtrain=Xt[:int(0.8*Xt.shape[0])]
ytrain=yt[:int(0.8*yt.shape[0])]

Xtest=Xt[int(0.8*Xt.shape[0]):]
ytest=yt[int(0.8*yt.shape[0]):]

# %%
X_train=Xtrain[:int(0.8*Xtrain.shape[0])]
y_train=ytrain[:int(0.8*ytrain.shape[0])]

X_test=Xtrain[int(0.8*Xtrain.shape[0]):]
y_test=ytrain[int(0.8*ytrain.shape[0]):]

# %% [markdown]
# model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ConvLSTM2D, Conv2D, BatchNormalization, Dropout

inputs = Input(shape=(Xt.shape[1:]))  # ventana temporal, alto, ancho, canales

x = ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False, activation='relu')(inputs)
x = BatchNormalization()(x)             # Normalización para estabilizar
x = Dropout(0.3)(x)                     # Dropout para evitar sobreajuste

x = Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu')(x)
x = BatchNormalization()(x)             # Otra capa de normalización
x = Dropout(0.3)(x)                     # Más dropout

outputs = Conv2D(filters=1, kernel_size=(3, 3), padding='same', activation='linear')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 3, 52, 49, 7)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 52, 49, 32)     │        45,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 52, 49, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 52, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 52, 49, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 52, 49, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 52, 49, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 52, 49, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,017 (195.38 KB)
#  Trainable params: 49,921 (195.00 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
path="/content/drive/MyDrive/investigacion/windows"

# %%
#early stopping
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#metrics
from tensorflow.keras.metrics import MeanAbsoluteError

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-8)
checkpoint= ModelCheckpoint(filepath=path+'model.keras', monitor='val_loss', save_best_only=True)

model.fit(Xtrain, ytrain, epochs=1000, batch_size=32,validation_data=(X_test,y_test), callbacks=[early_stopping, reduce_lr,checkpoint])
# Out:
# Epoch 1/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 104ms/step - loss: 0.9959 - mae: 0.7059 - val_loss: 0.0827 - val_mae: 0.1488 - learning_rate: 0.0010
# Epoch 2/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.1321 - mae: 0.2670 - val_loss: 0.0831 - val_mae: 0.1602 - learning_rate: 0.0010
# Epoch 3/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 0.0280 - mae: 0.1248 - val_loss: 0.0616 - val_mae: 0.1357 - learning_rate: 0.0010
# Epoch 4/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0098 - mae: 0.0707 - val_loss: 0.0301 - val_mae: 0.0934 - learning_rate: 0.0010
# Epoch 5/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0068 - mae: 0.0558 - val_loss: 0.0077 - val_mae: 0.0485 - learning_rate: 0.0010
# Epoch 6/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0059 - mae: 0.0507 - val_loss: 0.0014 - val_mae: 0.0219 - learning_rate: 0.0010
# Epoch 7/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0054 - mae: 0.0476 - val_loss: 6.8570e-04 - val_mae: 0.0180 - learning_rate: 0.0010
# Epoch 8/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0050 - mae: 0.0453 - val_loss: 5.1684e-04 - val_mae: 0.0157 - learning_rate: 0.0010
# Epoch 9/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0047 - mae: 0.0437 - val_loss: 4.5195e-04 - val_mae: 0.0142 - learning_rate: 0.0010
# Epoch 10/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0045 - mae: 0.0424 - val_loss: 4.0142e-04 - val_mae: 0.0131 - learning_rate: 0.0010
# Epoch 11/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0044 - mae: 0.0414 - val_loss: 3.7744e-04 - val_mae: 0.0127 - learning_rate: 0.0010
# Epoch 12/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0042 - mae: 0.0404 - val_loss: 3.6123e-04 - val_mae: 0.0120 - learning_rate: 0.0010
# Epoch 13/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0041 - mae: 0.0396 - val_loss: 3.3283e-04 - val_mae: 0.0115 - learning_rate: 0.0010
# Epoch 14/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0040 - mae: 0.0388 - val_loss: 2.9322e-04 - val_mae: 0.0102 - learning_rate: 0.0010
# Epoch 15/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0039 - mae: 0.0381 - val_loss: 3.1692e-04 - val_mae: 0.0105 - learning_rate: 0.0010
# Epoch 16/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0038 - mae: 0.0376 - val_loss: 5.2182e-04 - val_mae: 0.0129 - learning_rate: 0.0010
# Epoch 17/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0038 - mae: 0.0370 - val_loss: 3.6166e-04 - val_mae: 0.0112 - learning_rate: 0.0010
# Epoch 18/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0037 - mae: 0.0366 - val_loss: 3.6434e-04 - val_mae: 0.0108 - learning_rate: 0.0010
# Epoch 19/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0037 - mae: 0.0362 - val_loss: 4.3356e-04 - val_mae: 0.0116 - learning_rate: 0.0010
# Epoch 20/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0036 - mae: 0.0357 - val_loss: 6.5591e-04 - val_mae: 0.0137 - learning_rate: 0.0010
# Epoch 21/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0036 - mae: 0.0353 - val_loss: 5.2927e-04 - val_mae: 0.0121 - learning_rate: 0.0010
# Epoch 22/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0035 - mae: 0.0350 - val_loss: 4.0340e-04 - val_mae: 0.0106 - learning_rate: 0.0010
# Epoch 23/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0035 - mae: 0.0347 - val_loss: 4.3190e-04 - val_mae: 0.0110 - learning_rate: 0.0010
# Epoch 24/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0344 - val_loss: 3.6005e-04 - val_mae: 0.0101 - learning_rate: 0.0010
# Epoch 25/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0343 - val_loss: 2.7915e-04 - val_mae: 0.0090 - learning_rate: 1.0000e-04
# Epoch 26/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0342 - val_loss: 2.9760e-04 - val_mae: 0.0092 - learning_rate: 1.0000e-04
# Epoch 27/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0342 - val_loss: 2.9502e-04 - val_mae: 0.0092 - learning_rate: 1.0000e-04
# Epoch 28/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0342 - val_loss: 2.7482e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-04
# Epoch 29/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.0034 - mae: 0.0342 - val_loss: 3.2596e-04 - val_mae: 0.0098 - learning_rate: 1.0000e-04
# Epoch 30/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0342 - val_loss: 3.1913e-04 - val_mae: 0.0097 - learning_rate: 1.0000e-04
# Epoch 31/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0341 - val_loss: 2.4804e-04 - val_mae: 0.0085 - learning_rate: 1.0000e-04
# Epoch 32/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0341 - val_loss: 2.5824e-04 - val_mae: 0.0087 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0341 - val_loss: 2.4060e-04 - val_mae: 0.0084 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0341 - val_loss: 2.4510e-04 - val_mae: 0.0084 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.7599e-04 - val_mae: 0.0089 - learning_rate: 1.0000e-05
# Epoch 36/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.8177e-04 - val_mae: 0.0090 - learning_rate: 1.0000e-05
# Epoch 37/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.7375e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-05
# Epoch 38/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.7691e-04 - val_mae: 0.0089 - learning_rate: 1.0000e-05
# Epoch 39/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6894e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-05
# Epoch 40/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.8300e-04 - val_mae: 0.0090 - learning_rate: 1.0000e-05
# Epoch 41/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.9079e-04 - val_mae: 0.0091 - learning_rate: 1.0000e-05
# Epoch 42/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0341 - val_loss: 2.6659e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-05
# Epoch 43/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.7485e-04 - val_mae: 0.0089 - learning_rate: 1.0000e-05
# Epoch 44/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6637e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-05
# Epoch 45/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.7013e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 46/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6932e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 47/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6745e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 48/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6703e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 49/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6902e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 50/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6782e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 51/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6535e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 52/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.6861e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06
# Epoch 53/1000
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 0.0034 - mae: 0.0340 - val_loss: 2.7004e-04 - val_mae: 0.0088 - learning_rate: 1.0000e-06

# %%
#plot history
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
model.evaluate(Xtest,ytest)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 2.4008e-04 - mae: 0.0084
# [0.0002258562744827941, 0.008251458406448364]

# %%
ytest.shape
# Out:
# (1002, 52, 49)

# %%
#r2 score
from sklearn.metrics import r2_score
n=ytest.shape[0]
y_pred = model.predict(Xtest)
y_pred[ytest==0]=0
r2_score(ytest.reshape(n,-1), y_pred.reshape(n,-1))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step
# 0.6550134014921876

# %%
plt.subplot(1, 2, 1)
plt.title('Original')
plt.imshow(ytest[90])
plt.subplot(1, 2, 2)
plt.title('Predicted')
plt.imshow(y_pred[90])
plt.show()
