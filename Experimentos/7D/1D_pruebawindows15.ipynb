# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
# !pip install geopandas
# !pip install pykrige
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Collecting pykrige
#   Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from pykrige) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from pykrige) (1.16.2)
# Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.8 MB/s eta 0:00:00
# Installing collected packages: pykrige
# Successfully installed pykrige-1.7.3

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import tensorflow as tf
from keras import layers, models
from sklearn.pipeline import Pipeline
import pykrige #biblioteca de geoestadística
import pykrige.kriging_tools as kt #herramientas para exportar e importar archivos .asc con biblioteca PyKrige
from pykrige.ok import OrdinaryKriging #Kriging Ordinario con PyKrige

# %% [markdown]
# forecasting

# %%
path="/content/drive/MyDrive/investigacion/1D/datasetLCprueba2"
df=pd.read_csv(path+"/dataset2005-01-09.csv")
df.head()
# Out:
#          lat       lon     band1     band2     band3     band4     band5  \
# 0 -8789850.0  184950.0  0.105978  0.099330  0.069518  0.362668  0.197366
# 1 -8784900.0  174600.0  0.105689  0.095687  0.070707  0.330275  0.167146
# 2 -8775000.0  164700.0  0.105804  0.090551  0.068804  0.302913  0.142175
# 3 -8775000.0  169650.0  0.106262  0.085919  0.059622  0.293441  0.117007
# 4 -8775000.0  174600.0  0.106714  0.090143  0.063222  0.305589  0.153831
#
#         band6     band7  irradiance
# 0  296.785832  0.075079  205.371589
# 1  293.817967  0.068660  210.671487
# 2  292.549939  0.057090  208.897715
# 3  293.856536  0.042214  200.784402
# 4  294.796857  0.061334  202.307685

# %%
min_lat=df["lat"].min()
max_lat=df["lat"].max()
min_lon=df["lon"].min()
max_lon=df["lon"].max()
print(min_lat,max_lat,min_lon,max_lon)
# Out:
# -8789850.0 -8554950.0 45000.0 294750.0

# %%
lat=df['lat'].unique()
lon=df['lon'].unique()

lat=np.sort(lat)
lon=np.sort(lon)
dif_lat=np.diff(lat)
dif_lon=np.diff(lon)

min_dif_lat=np.min(dif_lat)
min_dif_lon=np.min(dif_lon)

print(min_dif_lat,min_dif_lon)
# Out:
# 4950.0 4950.0

# %%
def get_images(df,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  matrix_b1 = np.zeros((cols, rows))
  matrix_b2 = np.zeros((cols, rows))
  matrix_b3 = np.zeros((cols, rows))
  matrix_b4 = np.zeros((cols, rows))
  matrix_b5 = np.zeros((cols, rows))
  matrix_b6 = np.zeros((cols, rows))
  matrix_b7 = np.zeros((cols, rows))
  matrix_b8 = np.zeros((cols, rows))
  matrix_irradiance = np.zeros((cols, rows))

  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        matrix_b1[lon_index, lat_index] = row['band1']
        matrix_b2[lon_index, lat_index] = row['band2']
        matrix_b3[lon_index, lat_index] = row['band3']
        matrix_b4[lon_index, lat_index] = row['band4']
        matrix_b5[lon_index, lat_index] = row['band5']
        matrix_b6[lon_index, lat_index] = row['band6']
        matrix_b7[lon_index, lat_index] = row['band7']
        matrix_b8[lon_index, lat_index] = row['irradiance']

        matrix_irradiance[lon_index, lat_index] = row['irradiance']

  satelital_image = np.stack((matrix_b1, matrix_b2, matrix_b3, matrix_b4, matrix_b5, matrix_b6, matrix_b7), axis=-1)
  return satelital_image,matrix_irradiance

def get_dataframe(df,matrix,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  lat=[]
  lon=[]
  irradiance=[]
  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        lat.append(row['lat'])
        lon.append(row['lon'])
        irradiance.append(matrix[lon_index, lat_index])

  df_result=pd.DataFrame({'latitude':lat,'longitude':lon,'irradiance':irradiance})
  return df_result

# %%
satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
satelital_image.shape,matrix_irradiance.shape
# Out:
# ((52, 49, 7), (52, 49))

# %%
#nombre dce columnas
print(df.columns)
# Out:
# Index(['lat', 'lon', 'band1', 'band2', 'band3', 'band4', 'band5', 'band6',
#        'band7', 'irradiance'],
#       dtype='object')

# %%
for i in range(satelital_image.shape[2]):
  plt.title(f"Band {i+1}")
  plt.imshow(satelital_image[:,:,i])
  plt.show()

# %%
##cambiamos
X=[]
y=[]
dates=[]
# Load files every 4 days
day_interval = 4 # Changed from 3 to 4
count = 0

# Get a sorted list of filenames to ensure correct date order
filenames = sorted([f for f in os.listdir(path) if f.endswith(".csv")])

for filename in filenames:
  if count % day_interval == 0:
    print(filename)
    print("read file")
    df=pd.read_csv(path+"/"+filename)
    dates.append(filename.split(".")[0])
    print("get images 2 dataframe")
    satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
    print("append images")
    X.append(satelital_image)
    y.append(matrix_irradiance)

  count += 1

print(f"\nSe cargaron {len(X)} imágenes.")
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# get images 2 dataframe
# append images
# dataset2003-01-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-01-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2003-12-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-01-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-02-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-03-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-07-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2004-12-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-20.csv
# read file
# get images 2 dataframe
# append images
# ...
# append images
# dataset2014-03-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-18.csv
# read file
# get images 2 dataframe
# append images
#
# Se cargaron 1253 imágenes.

# %%
df
# Out:
#            lat       lon     band1     band2    band3     band4     band5  \
# 0   -8789850.0  184950.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 1   -8784900.0  174600.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 2   -8775000.0  164700.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 3   -8775000.0  169650.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 4   -8775000.0  174600.0  0.102325  0.079569  0.05199  0.268903  0.122978
# ..         ...       ...       ...       ...      ...       ...       ...
# 429 -8559900.0  154800.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 430 -8559900.0  169650.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 431 -8559900.0  174600.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 432 -8554950.0  154800.0  0.102325  0.079569  0.05199  0.268903  0.122978
# 433 -8554950.0  169650.0  0.102325  0.079569  0.05199  0.268903  0.122978
#
#           band6     band7  irradiance
# 0    295.799082  0.043425  204.451094
# 1    295.799082  0.043425  202.684933
# 2    295.799082  0.043425  199.904840
# 3    295.799082  0.043425  200.289560
# 4    295.799082  0.043425  200.693780
# ..          ...       ...         ...
# 429  295.799080  0.043425  211.393780
# 430  295.799082  0.043425  212.644351
# 431  295.799082  0.043425  213.129454
# 432  295.799080  0.043425  211.635261
# 433  295.799081  0.043425  212.899733
#
# [434 rows x 10 columns]

# %%
new_dates = []
for date in dates:
  new_dates.append(date.replace("dataset","").replace("landsat", ""))

# %%
#convert str to date
from datetime import datetime
new_dates = [datetime.strptime(date, '%Y-%m-%d') for date in new_dates]

# %%
X=np.array(X)

# %%
y=np.array(y)

# %%
X.shape,y.shape
# Out:
# ((1253, 52, 49, 7), (1253, 52, 49))

# %%
new_dates=np.array(new_dates)
index=np.argsort(new_dates)
X=X[index]
y=y[index]

# %%
#min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)
X.shape
# Out:
# (1253, 52, 49, 7)

# %%
y=scaler.fit_transform(y.reshape(-1, 1)).reshape(y.shape)
y.shape
# Out:
# (1253, 52, 49)

# %%
X.min(),X.max(),y.min(),y.max()
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# windows

# %%
#forecasting window
def window(X,y,v):
  yt=y[v:]
  Xt=[]
  for i in range(X.shape[0]-v):
    Xt.append(X[i:i+v])

  return np.array(Xt),yt

# %%
Xt,yt=window(X,y,15)
Xt.shape,yt.shape
# Out:
# ((1238, 15, 52, 49, 7), (1238, 52, 49))

# %%
Xt.shape[1:]
# Out:
# (15, 52, 49, 7)

# %%
Xt.shape
# Out:
# (1238, 15, 52, 49, 7)

# %%
Xtrain=Xt[:int(0.8*Xt.shape[0])]
ytrain=yt[:int(0.8*yt.shape[0])]

Xtest=Xt[int(0.8*Xt.shape[0]):]
ytest=yt[int(0.8*yt.shape[0]):]

# %%
X_train=Xtrain[:int(0.8*Xtrain.shape[0])]
y_train=ytrain[:int(0.8*ytrain.shape[0])]

X_test=Xtrain[int(0.8*Xtrain.shape[0]):]
y_test=ytrain[int(0.8*ytrain.shape[0]):]

# %% [markdown]
# model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ConvLSTM2D, Conv2D, BatchNormalization, Dropout

inputs = Input(shape=(Xt.shape[1:]))  # ventana temporal, alto, ancho, canales

x = ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False, activation='relu')(inputs)
x = BatchNormalization()(x)             # Normalización para estabilizar
x = Dropout(0.3)(x)                     # Dropout para evitar sobreajuste

x = Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu')(x)
x = BatchNormalization()(x)             # Otra capa de normalización
x = Dropout(0.3)(x)                     # Más dropout

outputs = Conv2D(filters=1, kernel_size=(3, 3), padding='same', activation='linear')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 15, 52, 49, 7)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 52, 49, 32)     │        45,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 52, 49, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 52, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 52, 49, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 52, 49, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 52, 49, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 52, 49, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,017 (195.38 KB)
#  Trainable params: 49,921 (195.00 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
path="/content/drive/MyDrive/investigacion/windows"

# %%
#early stopping
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#metrics
from tensorflow.keras.metrics import MeanAbsoluteError

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-8)
checkpoint= ModelCheckpoint(filepath=path+'model.keras', monitor='val_loss', save_best_only=True)

model.fit(Xtrain, ytrain, epochs=1000, batch_size=32,validation_data=(X_test,y_test), callbacks=[early_stopping, reduce_lr,checkpoint])
# Out:
# Epoch 1/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 24s 460ms/step - loss: 1.6217 - mae: 0.9500 - val_loss: 0.0650 - val_mae: 0.1668 - learning_rate: 0.0010
# Epoch 2/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - loss: 0.6262 - mae: 0.5908 - val_loss: 0.0469 - val_mae: 0.1313 - learning_rate: 0.0010
# Epoch 3/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 203ms/step - loss: 0.4002 - mae: 0.4764 - val_loss: 0.0492 - val_mae: 0.1195 - learning_rate: 0.0010
# Epoch 4/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - loss: 0.2718 - mae: 0.3983 - val_loss: 0.0518 - val_mae: 0.1161 - learning_rate: 0.0010
# Epoch 5/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - loss: 0.1833 - mae: 0.3307 - val_loss: 0.0502 - val_mae: 0.1162 - learning_rate: 0.0010
# Epoch 6/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 203ms/step - loss: 0.1238 - mae: 0.2729 - val_loss: 0.0482 - val_mae: 0.1153 - learning_rate: 0.0010
# Epoch 7/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step - loss: 0.0834 - mae: 0.2245 - val_loss: 0.0454 - val_mae: 0.1163 - learning_rate: 0.0010
# Epoch 8/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - loss: 0.0561 - mae: 0.1841 - val_loss: 0.0415 - val_mae: 0.1163 - learning_rate: 0.0010
# Epoch 9/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - loss: 0.0377 - mae: 0.1506 - val_loss: 0.0378 - val_mae: 0.1137 - learning_rate: 0.0010
# Epoch 10/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 6s 206ms/step - loss: 0.0260 - mae: 0.1243 - val_loss: 0.0325 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 11/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 210ms/step - loss: 0.0185 - mae: 0.1039 - val_loss: 0.0289 - val_mae: 0.1035 - learning_rate: 0.0010
# Epoch 12/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - loss: 0.0140 - mae: 0.0891 - val_loss: 0.0248 - val_mae: 0.0948 - learning_rate: 0.0010
# Epoch 13/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - loss: 0.0113 - mae: 0.0788 - val_loss: 0.0218 - val_mae: 0.0850 - learning_rate: 0.0010
# Epoch 14/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - loss: 0.0096 - mae: 0.0715 - val_loss: 0.0186 - val_mae: 0.0757 - learning_rate: 0.0010
# Epoch 15/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0085 - mae: 0.0664 - val_loss: 0.0142 - val_mae: 0.0670 - learning_rate: 0.0010
# Epoch 16/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - loss: 0.0078 - mae: 0.0625 - val_loss: 0.0113 - val_mae: 0.0573 - learning_rate: 0.0010
# Epoch 17/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0072 - mae: 0.0594 - val_loss: 0.0084 - val_mae: 0.0523 - learning_rate: 0.0010
# Epoch 18/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - loss: 0.0068 - mae: 0.0571 - val_loss: 0.0067 - val_mae: 0.0500 - learning_rate: 0.0010
# Epoch 19/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0065 - mae: 0.0551 - val_loss: 0.0055 - val_mae: 0.0461 - learning_rate: 0.0010
# Epoch 20/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - loss: 0.0062 - mae: 0.0533 - val_loss: 0.0034 - val_mae: 0.0462 - learning_rate: 0.0010
# Epoch 21/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 223ms/step - loss: 0.0059 - mae: 0.0518 - val_loss: 0.0024 - val_mae: 0.0411 - learning_rate: 0.0010
# Epoch 22/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - loss: 0.0057 - mae: 0.0504 - val_loss: 0.0028 - val_mae: 0.0474 - learning_rate: 0.0010
# Epoch 23/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - loss: 0.0054 - mae: 0.0489 - val_loss: 0.0068 - val_mae: 0.0768 - learning_rate: 0.0010
# Epoch 24/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - loss: 0.0052 - mae: 0.0478 - val_loss: 0.0113 - val_mae: 0.0991 - learning_rate: 0.0010
# Epoch 25/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0051 - mae: 0.0469 - val_loss: 0.0177 - val_mae: 0.1231 - learning_rate: 0.0010
# Epoch 26/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0050 - mae: 0.0461 - val_loss: 0.0187 - val_mae: 0.1274 - learning_rate: 0.0010
# Epoch 27/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0049 - mae: 0.0454 - val_loss: 0.0206 - val_mae: 0.1324 - learning_rate: 0.0010
# Epoch 28/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0048 - mae: 0.0448 - val_loss: 0.0153 - val_mae: 0.1128 - learning_rate: 0.0010
# Epoch 29/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0047 - mae: 0.0443 - val_loss: 0.0154 - val_mae: 0.1110 - learning_rate: 0.0010
# Epoch 30/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - loss: 0.0046 - mae: 0.0439 - val_loss: 0.0134 - val_mae: 0.1034 - learning_rate: 0.0010
# Epoch 31/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0046 - mae: 0.0434 - val_loss: 0.0126 - val_mae: 0.0993 - learning_rate: 0.0010
# Epoch 32/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - loss: 0.0045 - mae: 0.0430 - val_loss: 0.0063 - val_mae: 0.0683 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0045 - mae: 0.0431 - val_loss: 0.0029 - val_mae: 0.0445 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - loss: 0.0045 - mae: 0.0430 - val_loss: 0.0011 - val_mae: 0.0264 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - loss: 0.0045 - mae: 0.0430 - val_loss: 5.9964e-04 - val_mae: 0.0192 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - loss: 0.0045 - mae: 0.0429 - val_loss: 5.4690e-04 - val_mae: 0.0182 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0045 - mae: 0.0428 - val_loss: 4.3123e-04 - val_mae: 0.0158 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 223ms/step - loss: 0.0045 - mae: 0.0428 - val_loss: 3.1100e-04 - val_mae: 0.0127 - learning_rate: 1.0000e-04
# Epoch 39/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 209ms/step - loss: 0.0045 - mae: 0.0428 - val_loss: 3.1747e-04 - val_mae: 0.0128 - learning_rate: 1.0000e-04
# Epoch 40/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0045 - mae: 0.0428 - val_loss: 2.9746e-04 - val_mae: 0.0121 - learning_rate: 1.0000e-04
# Epoch 41/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0045 - mae: 0.0427 - val_loss: 2.8895e-04 - val_mae: 0.0117 - learning_rate: 1.0000e-04
# Epoch 42/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0045 - mae: 0.0426 - val_loss: 3.0057e-04 - val_mae: 0.0122 - learning_rate: 1.0000e-04
# Epoch 43/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0045 - mae: 0.0426 - val_loss: 3.4191e-04 - val_mae: 0.0115 - learning_rate: 1.0000e-04
# Epoch 44/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - loss: 0.0045 - mae: 0.0425 - val_loss: 2.8372e-04 - val_mae: 0.0113 - learning_rate: 1.0000e-04
# Epoch 45/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - loss: 0.0045 - mae: 0.0425 - val_loss: 3.7056e-04 - val_mae: 0.0118 - learning_rate: 1.0000e-04
# Epoch 46/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0045 - mae: 0.0425 - val_loss: 4.3244e-04 - val_mae: 0.0128 - learning_rate: 1.0000e-04
# Epoch 47/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0044 - mae: 0.0424 - val_loss: 3.2572e-04 - val_mae: 0.0114 - learning_rate: 1.0000e-04
# Epoch 48/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - loss: 0.0044 - mae: 0.0424 - val_loss: 3.7427e-04 - val_mae: 0.0120 - learning_rate: 1.0000e-04
# Epoch 49/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 3.6180e-04 - val_mae: 0.0118 - learning_rate: 1.0000e-05
# Epoch 50/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 3.9390e-04 - val_mae: 0.0122 - learning_rate: 1.0000e-05
# Epoch 51/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 3.9426e-04 - val_mae: 0.0122 - learning_rate: 1.0000e-05
# Epoch 52/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.4090e-04 - val_mae: 0.0129 - learning_rate: 1.0000e-05
# Epoch 53/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0045 - mae: 0.0424 - val_loss: 4.2009e-04 - val_mae: 0.0126 - learning_rate: 1.0000e-05
# Epoch 54/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0044 - mae: 0.0424 - val_loss: 4.1119e-04 - val_mae: 0.0124 - learning_rate: 1.0000e-05
# Epoch 55/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.4676e-04 - val_mae: 0.0130 - learning_rate: 1.0000e-05
# Epoch 56/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.4545e-04 - val_mae: 0.0130 - learning_rate: 1.0000e-05
# Epoch 57/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.6015e-04 - val_mae: 0.0132 - learning_rate: 1.0000e-05
# Epoch 58/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.6746e-04 - val_mae: 0.0133 - learning_rate: 1.0000e-05
# Epoch 59/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.7413e-04 - val_mae: 0.0134 - learning_rate: 1.0000e-06
# Epoch 60/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 214ms/step - loss: 0.0045 - mae: 0.0424 - val_loss: 4.6890e-04 - val_mae: 0.0134 - learning_rate: 1.0000e-06
# Epoch 61/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.7389e-04 - val_mae: 0.0135 - learning_rate: 1.0000e-06
# Epoch 62/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 216ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.7548e-04 - val_mae: 0.0135 - learning_rate: 1.0000e-06
# Epoch 63/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - loss: 0.0044 - mae: 0.0423 - val_loss: 4.8375e-04 - val_mae: 0.0136 - learning_rate: 1.0000e-06
# Epoch 64/1000
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - loss: 0.0044 - mae: 0.0422 - val_loss: 4.7984e-04 - val_mae: 0.0136 - learning_rate: 1.0000e-06

# %%
#plot history
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
model.evaluate(Xtest,ytest)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 2.6973e-04 - mae: 0.0111
# [0.00026556241209618747, 0.011011993512511253]

# %%
ytest.shape
# Out:
# (248, 52, 49)

# %%
#r2 score
from sklearn.metrics import r2_score
n=ytest.shape[0]
y_pred = model.predict(Xtest)
y_pred[ytest==0]=0
r2_score(ytest.reshape(n,-1), y_pred.reshape(n,-1))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step
# 0.661928663215598

# %%
plt.subplot(1, 2, 1)
plt.title('Original')
plt.imshow(ytest[90])
plt.subplot(1, 2, 2)
plt.title('Predicted')
plt.imshow(y_pred[90])
plt.show()
