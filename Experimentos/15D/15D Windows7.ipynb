# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
# !pip install geopandas
# !pip install pykrige
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Collecting pykrige
#   Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from pykrige) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from pykrige) (1.16.2)
# Downloading pykrige-1.7.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: pykrige
# Successfully installed pykrige-1.7.3

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import tensorflow as tf
from keras import layers, models
from sklearn.pipeline import Pipeline
import pykrige #biblioteca de geoestadística
import pykrige.kriging_tools as kt #herramientas para exportar e importar archivos .asc con biblioteca PyKrige
from pykrige.ok import OrdinaryKriging #Kriging Ordinario con PyKrige

# %% [markdown]
# forecasting

# %%
path="/content/drive/MyDrive/investigacion/15D/pruebadatasetLc"
df=pd.read_csv(path+"/landsat2003-01-01.csv")
df.head()
# Out:
#          lat       lon     band1     band2     band3     band4     band5  \
# 0 -8789850.0  184950.0  0.101755  0.078818  0.051683  0.264549  0.129877
# 1 -8784900.0  174600.0  0.103636  0.081440  0.051834  0.276332  0.131768
# 2 -8775000.0  164700.0  0.106230  0.095642  0.069535  0.328565  0.178510
# 3 -8775000.0  169650.0  0.106100  0.085670  0.058951  0.267595  0.123353
# 4 -8775000.0  174600.0  0.105858  0.082105  0.051419  0.279088  0.128134
#
#         band6     band7  irradiance
# 0  296.541341  0.043120  204.986188
# 1  296.468388  0.043376  202.845077
# 2  295.296542  0.075029  208.215425
# 3  294.432919  0.046396  200.875290
# 4  296.558853  0.040179  200.495335

# %%
min_lat=df["lat"].min()
max_lat=df["lat"].max()
min_lon=df["lon"].min()
max_lon=df["lon"].max()
print(min_lat,max_lat,min_lon,max_lon)
# Out:
# -8789850.0 -8554950.0 45000.0 294750.0

# %%
lat=df['lat'].unique()
lon=df['lon'].unique()

lat=np.sort(lat)
lon=np.sort(lon)
dif_lat=np.diff(lat)
dif_lon=np.diff(lon)

min_dif_lat=np.min(dif_lat)
min_dif_lon=np.min(dif_lon)

print(min_dif_lat,min_dif_lon)
# Out:
# 4950.0 4950.0

# %%
def get_images(df,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  matrix_b1 = np.zeros((cols, rows))
  matrix_b2 = np.zeros((cols, rows))
  matrix_b3 = np.zeros((cols, rows))
  matrix_b4 = np.zeros((cols, rows))
  matrix_b5 = np.zeros((cols, rows))
  matrix_b6 = np.zeros((cols, rows))
  matrix_b7 = np.zeros((cols, rows))
  matrix_b8 = np.zeros((cols, rows))
  matrix_irradiance = np.zeros((cols, rows))

  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        matrix_b1[lon_index, lat_index] = row['band1']
        matrix_b2[lon_index, lat_index] = row['band2']
        matrix_b3[lon_index, lat_index] = row['band3']
        matrix_b4[lon_index, lat_index] = row['band4']
        matrix_b5[lon_index, lat_index] = row['band5']
        matrix_b6[lon_index, lat_index] = row['band6']
        matrix_b7[lon_index, lat_index] = row['band7']
        matrix_b8[lon_index, lat_index] = row['irradiance']

        matrix_irradiance[lon_index, lat_index] = row['irradiance']

  satelital_image = np.stack((matrix_b1, matrix_b2, matrix_b3, matrix_b4, matrix_b5, matrix_b6, matrix_b7), axis=-1)
  return satelital_image,matrix_irradiance

def get_dataframe(df,matrix,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  lat=[]
  lon=[]
  irradiance=[]
  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        lat.append(row['lat'])
        lon.append(row['lon'])
        irradiance.append(matrix[lon_index, lat_index])

  df_result=pd.DataFrame({'latitude':lat,'longitude':lon,'irradiance':irradiance})
  return df_result

# %%
satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
satelital_image.shape,matrix_irradiance.shape
# Out:
# ((52, 49, 7), (52, 49))

# %%
#nombre dce columnas
print(df.columns)
# Out:
# Index(['lat', 'lon', 'band1', 'band2', 'band3', 'band4', 'band5', 'band6',
#        'band7', 'irradiance'],
#       dtype='object')

# %%
for i in range(satelital_image.shape[2]):
  plt.title(f"Band {i+1}")
  plt.imshow(satelital_image[:,:,i])
  plt.show()

# %%
X=[]
y=[]
dates=[]
for filename in os.listdir(path):
  print(filename)
  if filename.endswith(".csv"):
    print("read file")
    df=pd.read_csv(path+"/"+filename)
    dates.append(filename.split(".")[0])
    print("get images 2 dataframe")
    satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
    print("append images")
    X.append(satelital_image)
    y.append(matrix_irradiance)
# Out:
# landsat2003-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-01-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-01-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-03-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-03-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-04-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-04-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-05-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-05-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-05-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-06-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-06-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-07-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-07-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-08-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-08-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-09-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-09-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-10-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-10-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-11-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-11-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-12-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-12-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-01-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-02-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-02-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-04-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-04-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-05-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-06-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-06-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-07-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-07-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-08-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-09-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-10-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-10-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-11-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-11-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2004-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-03-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-03-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-04-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-04-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-05-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-05-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-06-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-06-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-07-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-07-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-08-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-08-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-09-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-10-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-10-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-11-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-11-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-12-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-12-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-01-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-02-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-02-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-03-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-03-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-04-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-05-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-05-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-06-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-06-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-07-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-07-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-09-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-09-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-10-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-10-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-10-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-12-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2011-12-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-02-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-02-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-03-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-04-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-04-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-05-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-05-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-06-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-06-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-07-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-08-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-08-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-09-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-09-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-10-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-11-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-11-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-12-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2012-12-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-01-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-01-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-02-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-03-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-03-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-04-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-04-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-05-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-05-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-06-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-07-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-07-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-08-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-08-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-09-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-09-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-10-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-11-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-11-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-12-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2013-12-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-01-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-02-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-02-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-03-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-03-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-04-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-04-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-05-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-05-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-06-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-06-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-29.csv
# read file
# get images 2 dataframe
# append images
# master

# %%
df
# Out:
#            lat       lon     band1     band2     band3     band4     band5  \
# 0   -8789850.0  184950.0  0.101974  0.099634  0.073342  0.360860  0.195844
# 1   -8784900.0  174600.0  0.103857  0.089601  0.055783  0.352965  0.163490
# 2   -8775000.0  164700.0  0.106647  0.092367  0.066178  0.321952  0.152637
# 3   -8775000.0  169650.0  0.106259  0.099159  0.070739  0.349668  0.172360
# 4   -8775000.0  174600.0  0.105815  0.085270  0.061636  0.277106  0.134790
# ..         ...       ...       ...       ...       ...       ...       ...
# 429 -8559900.0  154800.0  0.100841  0.076637  0.049078  0.251425  0.106560
# 430 -8559900.0  169650.0  0.101604  0.087636  0.064459  0.293446  0.138048
# 431 -8559900.0  174600.0  0.102107  0.085708  0.058372  0.302789  0.151979
# 432 -8554950.0  154800.0  0.100705  0.075834  0.048298  0.229172  0.100763
# 433 -8554950.0  169650.0  0.101108  0.084080  0.064161  0.286645  0.137886
#
#           band6     band7  irradiance
# 0    296.056202  0.081359  209.522754
# 1    296.313819  0.055147  202.118384
# 2    292.896598  0.064372  208.465556
# 3    294.501486  0.067822  208.093206
# 4    294.660504  0.051084  201.281203
# ..          ...       ...         ...
# 429  296.055115  0.035541  215.446933
# 430  292.643563  0.058337  218.571685
# 431  295.918571  0.055898  222.553519
# 432  296.017984  0.034161  215.414607
# 433  292.918583  0.058572  220.337008
#
# [434 rows x 10 columns]

# %%
new_dates = []
for date in dates:
  new_dates.append(date.replace("dataset","").replace("landsat", ""))

# %%
#convert str to date
from datetime import datetime
new_dates = [datetime.strptime(date, '%Y-%m-%d') for date in new_dates]

# %%
X=np.array(X)

# %%
y=np.array(y)

# %%
X.shape,y.shape
# Out:
# ((293, 52, 49, 7), (293, 52, 49))

# %%
new_dates=np.array(new_dates)
index=np.argsort(new_dates)
X=X[index]
y=y[index]

# %%
#min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)
X.shape
# Out:
# (293, 52, 49, 7)

# %%
y=scaler.fit_transform(y.reshape(-1, 1)).reshape(y.shape)
y.shape
# Out:
# (293, 52, 49)

# %%
X.min(),X.max(),y.min(),y.max()
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# windows

# %%
#forecasting window
def window(X,y,v):
  yt=y[v:]
  Xt=[]
  for i in range(X.shape[0]-v):
    Xt.append(X[i:i+v])

  return np.array(Xt),yt

# %%
Xt,yt=window(X,y,7)
Xt.shape,yt.shape
# Out:
# ((286, 7, 52, 49, 7), (286, 52, 49))

# %%
Xt.shape[1:]
# Out:
# (7, 52, 49, 7)

# %%
Xt.shape
# Out:
# (286, 7, 52, 49, 7)

# %%
Xtrain=Xt[:int(0.8*Xt.shape[0])]
ytrain=yt[:int(0.8*yt.shape[0])]

Xtest=Xt[int(0.8*Xt.shape[0]):]
ytest=yt[int(0.8*yt.shape[0]):]

# %%
X_train=Xtrain[:int(0.8*Xtrain.shape[0])]
y_train=ytrain[:int(0.8*ytrain.shape[0])]

X_test=Xtrain[int(0.8*Xtrain.shape[0]):]
y_test=ytrain[int(0.8*ytrain.shape[0]):]

# %% [markdown]
# model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ConvLSTM2D, Conv2D, BatchNormalization, Dropout

inputs = Input(shape=(Xt.shape[1:]))  # ventana temporal, alto, ancho, canales

x = ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False, activation='relu')(inputs)
x = BatchNormalization()(x)             # Normalización para estabilizar
x = Dropout(0.3)(x)                     # Dropout para evitar sobreajuste

x = Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu')(x)
x = BatchNormalization()(x)             # Otra capa de normalización
x = Dropout(0.3)(x)                     # Más dropout

outputs = Conv2D(filters=1, kernel_size=(3, 3), padding='same', activation='linear')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 7, 52, 49, 7)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d (ConvLSTM2D)        │ (None, 52, 49, 32)     │        45,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 52, 49, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 52, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 52, 49, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 52, 49, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 52, 49, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 52, 49, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,017 (195.38 KB)
#  Trainable params: 49,921 (195.00 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
path="/content/drive/MyDrive/investigacion/windows"

# %%
#early stopping
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#metrics
from tensorflow.keras.metrics import MeanAbsoluteError

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-8)
checkpoint= ModelCheckpoint(filepath=path+'model.keras', monitor='val_loss', save_best_only=True)

model.fit(Xtrain, ytrain, epochs=1000, batch_size=32,validation_data=(X_test,y_test), callbacks=[early_stopping, reduce_lr,checkpoint])
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 47s 5s/step - loss: 1.9663 - mae: 1.0502 - val_loss: 0.1039 - val_mae: 0.1579 - learning_rate: 0.0010
# Epoch 2/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - loss: 1.1023 - mae: 0.7899 - val_loss: 0.1110 - val_mae: 0.1627 - learning_rate: 0.0010
# Epoch 3/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - loss: 0.8395 - mae: 0.6870 - val_loss: 0.0979 - val_mae: 0.1578 - learning_rate: 0.0010
# Epoch 4/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.6927 - mae: 0.6237 - val_loss: 0.0874 - val_mae: 0.1504 - learning_rate: 0.0010
# Epoch 5/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.5928 - mae: 0.5767 - val_loss: 0.0860 - val_mae: 0.1450 - learning_rate: 0.0010
# Epoch 6/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.5124 - mae: 0.5356 - val_loss: 0.0870 - val_mae: 0.1437 - learning_rate: 0.0010
# Epoch 7/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.4525 - mae: 0.5019 - val_loss: 0.0835 - val_mae: 0.1387 - learning_rate: 0.0010
# Epoch 8/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.3996 - mae: 0.4714 - val_loss: 0.0801 - val_mae: 0.1370 - learning_rate: 0.0010
# Epoch 9/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.3583 - mae: 0.4452 - val_loss: 0.0764 - val_mae: 0.1363 - learning_rate: 0.0010
# Epoch 10/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - loss: 0.3177 - mae: 0.4189 - val_loss: 0.0749 - val_mae: 0.1359 - learning_rate: 0.0010
# Epoch 11/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.2812 - mae: 0.3947 - val_loss: 0.0722 - val_mae: 0.1336 - learning_rate: 0.0010
# Epoch 12/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.2530 - mae: 0.3741 - val_loss: 0.0720 - val_mae: 0.1342 - learning_rate: 0.0010
# Epoch 13/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.2257 - mae: 0.3541 - val_loss: 0.0704 - val_mae: 0.1330 - learning_rate: 0.0010
# Epoch 14/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.2026 - mae: 0.3356 - val_loss: 0.0702 - val_mae: 0.1317 - learning_rate: 0.0010
# Epoch 15/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.1810 - mae: 0.3181 - val_loss: 0.0696 - val_mae: 0.1306 - learning_rate: 0.0010
# Epoch 16/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.1616 - mae: 0.3015 - val_loss: 0.0690 - val_mae: 0.1291 - learning_rate: 0.0010
# Epoch 17/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - loss: 0.1448 - mae: 0.2858 - val_loss: 0.0688 - val_mae: 0.1271 - learning_rate: 0.0010
# Epoch 18/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.1302 - mae: 0.2713 - val_loss: 0.0684 - val_mae: 0.1264 - learning_rate: 0.0010
# Epoch 19/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.1153 - mae: 0.2557 - val_loss: 0.0687 - val_mae: 0.1256 - learning_rate: 0.0010
# Epoch 20/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.1039 - mae: 0.2429 - val_loss: 0.0679 - val_mae: 0.1242 - learning_rate: 0.0010
# Epoch 21/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0927 - mae: 0.2302 - val_loss: 0.0673 - val_mae: 0.1226 - learning_rate: 0.0010
# Epoch 22/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0823 - mae: 0.2170 - val_loss: 0.0665 - val_mae: 0.1202 - learning_rate: 0.0010
# Epoch 23/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0736 - mae: 0.2055 - val_loss: 0.0653 - val_mae: 0.1185 - learning_rate: 0.0010
# Epoch 24/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0664 - mae: 0.1953 - val_loss: 0.0648 - val_mae: 0.1182 - learning_rate: 0.0010
# Epoch 25/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0595 - mae: 0.1847 - val_loss: 0.0643 - val_mae: 0.1172 - learning_rate: 0.0010
# Epoch 26/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0533 - mae: 0.1750 - val_loss: 0.0634 - val_mae: 0.1162 - learning_rate: 0.0010
# Epoch 27/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0479 - mae: 0.1660 - val_loss: 0.0624 - val_mae: 0.1150 - learning_rate: 0.0010
# Epoch 28/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0428 - mae: 0.1569 - val_loss: 0.0618 - val_mae: 0.1140 - learning_rate: 0.0010
# Epoch 29/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0384 - mae: 0.1484 - val_loss: 0.0607 - val_mae: 0.1131 - learning_rate: 0.0010
# Epoch 30/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 81s 5s/step - loss: 0.0347 - mae: 0.1410 - val_loss: 0.0593 - val_mae: 0.1124 - learning_rate: 0.0010
# Epoch 31/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0311 - mae: 0.1335 - val_loss: 0.0583 - val_mae: 0.1114 - learning_rate: 0.0010
# Epoch 32/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0281 - mae: 0.1268 - val_loss: 0.0571 - val_mae: 0.1095 - learning_rate: 0.0010
# Epoch 33/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0256 - mae: 0.1208 - val_loss: 0.0559 - val_mae: 0.1085 - learning_rate: 0.0010
# Epoch 34/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0233 - mae: 0.1149 - val_loss: 0.0547 - val_mae: 0.1081 - learning_rate: 0.0010
# Epoch 35/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0212 - mae: 0.1093 - val_loss: 0.0538 - val_mae: 0.1077 - learning_rate: 0.0010
# Epoch 36/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0195 - mae: 0.1047 - val_loss: 0.0525 - val_mae: 0.1065 - learning_rate: 0.0010
# Epoch 37/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0178 - mae: 0.0997 - val_loss: 0.0510 - val_mae: 0.1046 - learning_rate: 0.0010
# Epoch 38/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0165 - mae: 0.0956 - val_loss: 0.0495 - val_mae: 0.1034 - learning_rate: 0.0010
# Epoch 39/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0152 - mae: 0.0917 - val_loss: 0.0482 - val_mae: 0.1025 - learning_rate: 0.0010
# Epoch 40/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0142 - mae: 0.0882 - val_loss: 0.0468 - val_mae: 0.1017 - learning_rate: 0.0010
# Epoch 41/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0133 - mae: 0.0848 - val_loss: 0.0455 - val_mae: 0.1001 - learning_rate: 0.0010
# Epoch 42/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0125 - mae: 0.0821 - val_loss: 0.0440 - val_mae: 0.0985 - learning_rate: 0.0010
# Epoch 43/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0117 - mae: 0.0792 - val_loss: 0.0425 - val_mae: 0.0973 - learning_rate: 0.0010
# Epoch 44/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0111 - mae: 0.0767 - val_loss: 0.0412 - val_mae: 0.0958 - learning_rate: 0.0010
# Epoch 45/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0106 - mae: 0.0745 - val_loss: 0.0396 - val_mae: 0.0943 - learning_rate: 0.0010
# Epoch 46/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0101 - mae: 0.0725 - val_loss: 0.0383 - val_mae: 0.0927 - learning_rate: 0.0010
# Epoch 47/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0097 - mae: 0.0708 - val_loss: 0.0371 - val_mae: 0.0912 - learning_rate: 0.0010
# Epoch 48/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0094 - mae: 0.0692 - val_loss: 0.0358 - val_mae: 0.0895 - learning_rate: 0.0010
# Epoch 49/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0091 - mae: 0.0676 - val_loss: 0.0342 - val_mae: 0.0881 - learning_rate: 0.0010
# Epoch 50/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0087 - mae: 0.0663 - val_loss: 0.0332 - val_mae: 0.0868 - learning_rate: 0.0010
# Epoch 51/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0086 - mae: 0.0655 - val_loss: 0.0320 - val_mae: 0.0854 - learning_rate: 0.0010
# Epoch 52/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0083 - mae: 0.0639 - val_loss: 0.0307 - val_mae: 0.0836 - learning_rate: 0.0010
# Epoch 53/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0080 - mae: 0.0628 - val_loss: 0.0295 - val_mae: 0.0819 - learning_rate: 0.0010
# Epoch 54/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0079 - mae: 0.0622 - val_loss: 0.0282 - val_mae: 0.0805 - learning_rate: 0.0010
# Epoch 55/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0078 - mae: 0.0614 - val_loss: 0.0268 - val_mae: 0.0787 - learning_rate: 0.0010
# Epoch 56/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0076 - mae: 0.0604 - val_loss: 0.0254 - val_mae: 0.0767 - learning_rate: 0.0010
# Epoch 57/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0075 - mae: 0.0599 - val_loss: 0.0242 - val_mae: 0.0746 - learning_rate: 0.0010
# Epoch 58/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0073 - mae: 0.0589 - val_loss: 0.0229 - val_mae: 0.0730 - learning_rate: 0.0010
# Epoch 59/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0073 - mae: 0.0586 - val_loss: 0.0217 - val_mae: 0.0713 - learning_rate: 0.0010
# Epoch 60/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0071 - mae: 0.0579 - val_loss: 0.0203 - val_mae: 0.0692 - learning_rate: 0.0010
# Epoch 61/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0070 - mae: 0.0572 - val_loss: 0.0190 - val_mae: 0.0669 - learning_rate: 0.0010
# Epoch 62/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0069 - mae: 0.0568 - val_loss: 0.0177 - val_mae: 0.0647 - learning_rate: 0.0010
# Epoch 63/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0068 - mae: 0.0561 - val_loss: 0.0163 - val_mae: 0.0629 - learning_rate: 0.0010
# Epoch 64/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0068 - mae: 0.0559 - val_loss: 0.0153 - val_mae: 0.0608 - learning_rate: 0.0010
# Epoch 65/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0067 - mae: 0.0554 - val_loss: 0.0141 - val_mae: 0.0587 - learning_rate: 0.0010
# Epoch 66/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0066 - mae: 0.0550 - val_loss: 0.0130 - val_mae: 0.0567 - learning_rate: 0.0010
# Epoch 67/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - loss: 0.0065 - mae: 0.0546 - val_loss: 0.0119 - val_mae: 0.0547 - learning_rate: 0.0010
# Epoch 68/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0064 - mae: 0.0540 - val_loss: 0.0109 - val_mae: 0.0525 - learning_rate: 0.0010
# Epoch 69/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0064 - mae: 0.0537 - val_loss: 0.0099 - val_mae: 0.0502 - learning_rate: 0.0010
# Epoch 70/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0063 - mae: 0.0534 - val_loss: 0.0088 - val_mae: 0.0482 - learning_rate: 0.0010
# Epoch 71/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0063 - mae: 0.0531 - val_loss: 0.0079 - val_mae: 0.0459 - learning_rate: 0.0010
# Epoch 72/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0062 - mae: 0.0527 - val_loss: 0.0071 - val_mae: 0.0446 - learning_rate: 0.0010
# Epoch 73/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0062 - mae: 0.0525 - val_loss: 0.0066 - val_mae: 0.0428 - learning_rate: 0.0010
# Epoch 74/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0060 - mae: 0.0519 - val_loss: 0.0055 - val_mae: 0.0411 - learning_rate: 0.0010
# Epoch 75/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0060 - mae: 0.0518 - val_loss: 0.0050 - val_mae: 0.0391 - learning_rate: 0.0010
# Epoch 76/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0060 - mae: 0.0515 - val_loss: 0.0043 - val_mae: 0.0384 - learning_rate: 0.0010
# Epoch 77/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0059 - mae: 0.0511 - val_loss: 0.0039 - val_mae: 0.0377 - learning_rate: 0.0010
# Epoch 78/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0059 - mae: 0.0509 - val_loss: 0.0034 - val_mae: 0.0369 - learning_rate: 0.0010
# Epoch 79/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0058 - mae: 0.0506 - val_loss: 0.0030 - val_mae: 0.0355 - learning_rate: 0.0010
# Epoch 80/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0058 - mae: 0.0503 - val_loss: 0.0025 - val_mae: 0.0349 - learning_rate: 0.0010
# Epoch 81/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0057 - mae: 0.0500 - val_loss: 0.0023 - val_mae: 0.0351 - learning_rate: 0.0010
# Epoch 82/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0057 - mae: 0.0498 - val_loss: 0.0020 - val_mae: 0.0352 - learning_rate: 0.0010
# Epoch 83/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0056 - mae: 0.0496 - val_loss: 0.0019 - val_mae: 0.0346 - learning_rate: 0.0010
# Epoch 84/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0056 - mae: 0.0494 - val_loss: 0.0018 - val_mae: 0.0358 - learning_rate: 0.0010
# Epoch 85/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0056 - mae: 0.0491 - val_loss: 0.0019 - val_mae: 0.0370 - learning_rate: 0.0010
# Epoch 86/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0055 - mae: 0.0489 - val_loss: 0.0018 - val_mae: 0.0372 - learning_rate: 0.0010
# Epoch 87/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0055 - mae: 0.0486 - val_loss: 0.0019 - val_mae: 0.0390 - learning_rate: 0.0010
# Epoch 88/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0055 - mae: 0.0485 - val_loss: 0.0021 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 89/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 44s 5s/step - loss: 0.0055 - mae: 0.0483 - val_loss: 0.0020 - val_mae: 0.0404 - learning_rate: 0.0010
# Epoch 90/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0054 - mae: 0.0480 - val_loss: 0.0024 - val_mae: 0.0438 - learning_rate: 0.0010
# Epoch 91/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0054 - mae: 0.0479 - val_loss: 0.0023 - val_mae: 0.0435 - learning_rate: 0.0010
# Epoch 92/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0053 - mae: 0.0476 - val_loss: 0.0024 - val_mae: 0.0445 - learning_rate: 0.0010
# Epoch 93/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0475 - val_loss: 0.0024 - val_mae: 0.0444 - learning_rate: 0.0010
# Epoch 94/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0053 - mae: 0.0472 - val_loss: 0.0021 - val_mae: 0.0407 - learning_rate: 1.0000e-04
# Epoch 95/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0473 - val_loss: 0.0018 - val_mae: 0.0376 - learning_rate: 1.0000e-04
# Epoch 96/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0053 - mae: 0.0473 - val_loss: 0.0016 - val_mae: 0.0347 - learning_rate: 1.0000e-04
# Epoch 97/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0473 - val_loss: 0.0014 - val_mae: 0.0319 - learning_rate: 1.0000e-04
# Epoch 98/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0471 - val_loss: 0.0012 - val_mae: 0.0295 - learning_rate: 1.0000e-04
# Epoch 99/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0472 - val_loss: 0.0012 - val_mae: 0.0281 - learning_rate: 1.0000e-04
# Epoch 100/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0053 - mae: 0.0474 - val_loss: 0.0011 - val_mae: 0.0268 - learning_rate: 1.0000e-04
# Epoch 101/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0053 - mae: 0.0472 - val_loss: 0.0010 - val_mae: 0.0256 - learning_rate: 1.0000e-04
# Epoch 102/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0053 - mae: 0.0472 - val_loss: 9.7104e-04 - val_mae: 0.0246 - learning_rate: 1.0000e-04
# Epoch 103/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0471 - val_loss: 9.0179e-04 - val_mae: 0.0233 - learning_rate: 1.0000e-04
# Epoch 104/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0471 - val_loss: 8.4409e-04 - val_mae: 0.0221 - learning_rate: 1.0000e-04
# Epoch 105/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0472 - val_loss: 8.0488e-04 - val_mae: 0.0211 - learning_rate: 1.0000e-04
# Epoch 106/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0471 - val_loss: 7.7512e-04 - val_mae: 0.0204 - learning_rate: 1.0000e-04
# Epoch 107/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0471 - val_loss: 7.4878e-04 - val_mae: 0.0197 - learning_rate: 1.0000e-04
# Epoch 108/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0053 - mae: 0.0472 - val_loss: 7.2837e-04 - val_mae: 0.0191 - learning_rate: 1.0000e-04
# Epoch 109/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 7.1484e-04 - val_mae: 0.0188 - learning_rate: 1.0000e-04
# Epoch 110/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0052 - mae: 0.0470 - val_loss: 7.0332e-04 - val_mae: 0.0184 - learning_rate: 1.0000e-04
# Epoch 111/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0470 - val_loss: 6.9071e-04 - val_mae: 0.0180 - learning_rate: 1.0000e-04
# Epoch 112/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.7867e-04 - val_mae: 0.0176 - learning_rate: 1.0000e-04
# Epoch 113/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0470 - val_loss: 6.6926e-04 - val_mae: 0.0174 - learning_rate: 1.0000e-04
# Epoch 114/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0053 - mae: 0.0471 - val_loss: 6.6954e-04 - val_mae: 0.0171 - learning_rate: 1.0000e-04
# Epoch 115/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.6331e-04 - val_mae: 0.0169 - learning_rate: 1.0000e-04
# Epoch 116/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.5319e-04 - val_mae: 0.0166 - learning_rate: 1.0000e-04
# Epoch 117/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.4543e-04 - val_mae: 0.0164 - learning_rate: 1.0000e-04
# Epoch 118/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.4791e-04 - val_mae: 0.0163 - learning_rate: 1.0000e-04
# Epoch 119/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 6.4808e-04 - val_mae: 0.0162 - learning_rate: 1.0000e-05
# Epoch 120/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 6.4832e-04 - val_mae: 0.0162 - learning_rate: 1.0000e-05
# Epoch 121/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0470 - val_loss: 6.5019e-04 - val_mae: 0.0161 - learning_rate: 1.0000e-05
# Epoch 122/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.5322e-04 - val_mae: 0.0161 - learning_rate: 1.0000e-05
# Epoch 123/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0467 - val_loss: 6.5629e-04 - val_mae: 0.0161 - learning_rate: 1.0000e-05
# Epoch 124/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0052 - mae: 0.0470 - val_loss: 6.5692e-04 - val_mae: 0.0161 - learning_rate: 1.0000e-05
# Epoch 125/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 6.5752e-04 - val_mae: 0.0161 - learning_rate: 1.0000e-05
# Epoch 126/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 42s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.6074e-04 - val_mae: 0.0162 - learning_rate: 1.0000e-05
# Epoch 127/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0053 - mae: 0.0469 - val_loss: 6.6524e-04 - val_mae: 0.0162 - learning_rate: 1.0000e-05
# Epoch 128/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 6.7109e-04 - val_mae: 0.0162 - learning_rate: 1.0000e-05
# Epoch 129/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 6.7631e-04 - val_mae: 0.0163 - learning_rate: 1.0000e-06
# Epoch 130/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.8161e-04 - val_mae: 0.0163 - learning_rate: 1.0000e-06
# Epoch 131/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 6.8669e-04 - val_mae: 0.0163 - learning_rate: 1.0000e-06
# Epoch 132/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.9240e-04 - val_mae: 0.0164 - learning_rate: 1.0000e-06
# Epoch 133/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 6.9801e-04 - val_mae: 0.0164 - learning_rate: 1.0000e-06
# Epoch 134/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 7.0256e-04 - val_mae: 0.0165 - learning_rate: 1.0000e-06
# Epoch 135/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 7.0628e-04 - val_mae: 0.0165 - learning_rate: 1.0000e-06
# Epoch 136/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0468 - val_loss: 7.1159e-04 - val_mae: 0.0166 - learning_rate: 1.0000e-06
# Epoch 137/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 5s/step - loss: 0.0052 - mae: 0.0469 - val_loss: 7.1449e-04 - val_mae: 0.0166 - learning_rate: 1.0000e-06

# %%
#plot history
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
model.evaluate(Xtest,ytest)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 6.0040e-04 - mae: 0.0160
# [0.0005986482137814164, 0.015949342399835587]

# %%
ytest.shape
# Out:
# (58, 52, 49)

# %%
#r2 score
from sklearn.metrics import r2_score
n=ytest.shape[0]
y_pred = model.predict(Xtest)
y_pred[ytest==0]=0
r2_score(ytest.reshape(n,-1), y_pred.reshape(n,-1))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# 0.21697099686134272

# %%
plt.subplot(1, 2, 1)
plt.title('Original')
plt.imshow(ytest[90])
plt.subplot(1, 2, 2)
plt.title('Predicted')
plt.imshow(y_pred[90])
plt.show()
