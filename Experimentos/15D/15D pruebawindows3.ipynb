# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
# !pip install geopandas
# !pip install pykrige
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Requirement already satisfied: pykrige in /usr/local/lib/python3.12/dist-packages (1.7.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from pykrige) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from pykrige) (1.16.2)

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import tensorflow as tf
from keras import layers, models
from sklearn.pipeline import Pipeline
import pykrige #biblioteca de geoestadística
import pykrige.kriging_tools as kt #herramientas para exportar e importar archivos .asc con biblioteca PyKrige
from pykrige.ok import OrdinaryKriging #Kriging Ordinario con PyKrige

# %% [markdown]
# forecasting

# %%
path="/content/drive/MyDrive/investigacion/datasetLC"
df=pd.read_csv(path+"/dataset2005-01-09.csv")
df.head()
# Out:
#          lat       lon      band1        band2        band3        band4  \
# 0 -8789850.0  184950.0  2790.0813  4296.806168  2872.552727  2930.404799
# 1 -8784900.0  174600.0  2790.0813  4296.806168  2872.552727  2930.404799
# 2 -8775000.0  169650.0  3114.1877  4332.650201  3231.588515  3286.695698
# 3 -8775000.0  174600.0  2790.0813  4296.806168  2872.552727  2930.404799
# 4 -8775000.0  184950.0  2790.0813  4296.806168  2872.552727  2930.404799
#
#          band5        band6        band7  irradiance
# 0  4249.742666  3006.705973  1823.397754  206.626943
# 1  4249.742666  3006.705973  1823.397754  205.608576
# 2  4235.390294  3102.295887  1894.808666  194.739615
# 3  4249.742666  3006.705973  1823.397754  204.346091
# 4  4249.742666  3006.705973  1823.397754  204.887983

# %%
min_lat=df["lat"].min()
max_lat=df["lat"].max()
min_lon=df["lon"].min()
max_lon=df["lon"].max()
print(min_lat,max_lat,min_lon,max_lon)
# Out:
# -8789850.0 -8554950.0 45000.0 294750.0

# %%
lat=df['lat'].unique()
lon=df['lon'].unique()

lat=np.sort(lat)
lon=np.sort(lon)
dif_lat=np.diff(lat)
dif_lon=np.diff(lon)

min_dif_lat=np.min(dif_lat)
min_dif_lon=np.min(dif_lon)

print(min_dif_lat,min_dif_lon)
# Out:
# 4950.0 4950.0

# %%
def get_images(df,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  matrix_b1 = np.zeros((cols, rows))
  matrix_b2 = np.zeros((cols, rows))
  matrix_b3 = np.zeros((cols, rows))
  matrix_b4 = np.zeros((cols, rows))
  matrix_b5 = np.zeros((cols, rows))
  matrix_b6 = np.zeros((cols, rows))
  matrix_b7 = np.zeros((cols, rows))
  matrix_b8 = np.zeros((cols, rows))
  matrix_irradiance = np.zeros((cols, rows))

  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        matrix_b1[lon_index, lat_index] = row['band1']
        matrix_b2[lon_index, lat_index] = row['band2']
        matrix_b3[lon_index, lat_index] = row['band3']
        matrix_b4[lon_index, lat_index] = row['band4']
        matrix_b5[lon_index, lat_index] = row['band5']
        matrix_b6[lon_index, lat_index] = row['band6']
        matrix_b7[lon_index, lat_index] = row['band7']
        matrix_b8[lon_index, lat_index] = row['irradiance']

        matrix_irradiance[lon_index, lat_index] = row['irradiance']

  satelital_image = np.stack((matrix_b1, matrix_b2, matrix_b3, matrix_b4, matrix_b5, matrix_b6, matrix_b7), axis=-1)
  return satelital_image,matrix_irradiance

def get_dataframe(df,matrix,max_lat,min_lat,max_lon,min_lon):
  rows = int(np.ceil((max_lat - min_lat) / 4950)) + 1
  cols = int(np.ceil((max_lon - min_lon) / 4950)) + 1
  lat=[]
  lon=[]
  irradiance=[]
  # Llenar la matriz con los valores de irradiancia
  for index, row in df.iterrows():
      lat_index = int(np.floor((row['lat'] - min_lat) / 4950))
      lon_index = int(np.floor((max_lon-row['lon']) / 4950))
      if 0 <= lat_index < rows and 0 <= lon_index < cols:
        lat.append(row['lat'])
        lon.append(row['lon'])
        irradiance.append(matrix[lon_index, lat_index])

  df_result=pd.DataFrame({'latitude':lat,'longitude':lon,'irradiance':irradiance})
  return df_result

# %%
satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
satelital_image.shape,matrix_irradiance.shape
# Out:
# ((52, 49, 7), (52, 49))

# %%
#nombre dce columnas
print(df.columns)
# Out:
# Index(['lat', 'lon', 'band1', 'band2', 'band3', 'band4', 'band5', 'band6',
#        'band7', 'irradiance'],
#       dtype='object')

# %%
for i in range(satelital_image.shape[2]):
  plt.title(f"Band {i+1}")
  plt.imshow(satelital_image[:,:,i])
  plt.show()

# %%
X=[]
y=[]
dates=[]
for filename in os.listdir(path):
  print(filename)
  if filename.endswith(".csv"):
    print("read file")
    df=pd.read_csv(path+"/"+filename)
    dates.append(filename.split(".")[0])
    print("get images 2 dataframe")
    satelital_image,matrix_irradiance=get_images(df,max_lat,min_lat,max_lon,min_lon)
    print("append images")
    X.append(satelital_image)
    y.append(matrix_irradiance)
# Out:
# dataset2007-12-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-12-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-01-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-02-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2008-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2009-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-01-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-02-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-03-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-04-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-05-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-06-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-07-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-08-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-09-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-10-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-11-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2010-12-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-01-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-02-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2011-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-11-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2012-12-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-01-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-02-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-03-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-04-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-05-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-06-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-07-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-08-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-09-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-10-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-11-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2013-12-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-01-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-02-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-03-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-04-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-05-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-06-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-07-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-08-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-09-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-10-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-11-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2014-12-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-01-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-02-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-03-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-04-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-05-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-06-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-07-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-08-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-09-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-10-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-11-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2015-12-27.csv
# read file
# get images 2 dataframe
# append images
# Master
# landsat2003-01-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2003-01-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-05-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-06-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-07-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-08-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-09-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-10-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-11-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2005-12-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-03-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-05-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-06-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-07-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-08-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-09-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-10-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-11-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2006-12-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-01-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-02-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-03-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-04-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-05-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-06-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-07-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-08-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-09-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-10-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-11-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2007-12-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-01-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-02-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-03-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-04-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-05-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-06-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-07-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-08-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-09-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-10-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2008-12-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-04-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-05-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-06-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-07-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-08-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-11-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2009-12-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-01-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-02-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2010-03-07.csv
# read file
# ...
# read file
# get images 2 dataframe
# append images
# landsat2014-06-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-07-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-08-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-09-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-10-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-11-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2014-12-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-01-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-02-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-03-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-04-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-03.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-10.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-17.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-24.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-05-31.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-07.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-14.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-21.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-06-28.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-05.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-12.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-19.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-07-26.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-02.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-09.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-16.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-23.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-08-30.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-09-27.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-04.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-11.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-18.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-10-25.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-01.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-08.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-15.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-22.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-06.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-11-29.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-13.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-20.csv
# read file
# get images 2 dataframe
# append images
# landsat2015-12-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-01-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-02-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-03-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-04-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-05-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-06-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-07-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-08-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-09-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-10-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-11-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2005-12-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-01-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-02-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-03-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-04-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-05-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-06-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-07-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-08-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-09-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-10-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-11-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2006-12-31.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-01-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-02-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-03-25.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-04-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-06.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-13.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-20.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-05-27.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-03.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-10.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-17.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-06-24.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-01.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-08.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-15.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-22.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-07-29.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-05.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-12.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-19.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-08-26.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-02.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-09.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-16.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-23.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-09-30.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-07.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-14.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-21.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-10-28.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-04.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-11.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-18.csv
# read file
# get images 2 dataframe
# append images
# dataset2007-11-25.csv
# read file
# get images 2 dataframe
# append images

# %%
df
# Out:
#            lat       lon       band1        band2        band3        band4  \
# 0   -8789850.0  184950.0  2600.60160  4140.856736  2709.872007  2785.791894
# 1   -8784900.0  174600.0  2776.75950  4285.822593  2872.552727  2930.404799
# 2   -8775000.0  169650.0  2915.45020  4218.441279  3023.498658  3074.688459
# 3   -8775000.0  174600.0  2867.51070  4251.324347  2927.876048  2972.951782
# 4   -8775000.0  184950.0  2734.60450  4202.110522  2813.390039  2862.694580
# ..         ...       ...         ...          ...          ...          ...
# 440 -8559900.0  154800.0  1425.99650  4396.399691  2363.099493  2437.262933
# 441 -8559900.0  169650.0  1152.64070  4396.399691  2332.001153  2434.169982
# 442 -8559900.0  174600.0  1009.16693  4396.399691  2284.171808  2389.341566
# 443 -8554950.0  154800.0  1494.89360  4396.399686  2398.729335  2461.871733
# 444 -8554950.0  169650.0  1204.29750  4396.399691  2332.001153  2434.169982
#
#            band5        band6        band7  irradiance
# 0    4140.706210  2963.274021  1784.329454  210.533650
# 1    4249.742666  3006.705973  1823.397754  205.740234
# 2    4226.428845  3028.295523  1836.341753  200.223057
# 3    4242.247234  3010.294056  1818.836489  202.846861
# 4    4201.708270  2983.295913  1766.467729  206.666793
# ..           ...          ...          ...         ...
# 440  3949.681537  2893.213259  1732.102615  218.586562
# 441  3940.157740  2884.177609  1725.747886  216.069716
# 442  3899.345068  2884.177609  1725.747886  215.432141
# 443  3982.600928  2896.688040  1729.568515  219.332059
# 444  3940.157740  2884.177609  1725.747886  216.326479
#
# [445 rows x 10 columns]

# %%
new_dates = []
for date in dates:
  new_dates.append(date.replace("dataset","").replace("landsat", ""))

# %%
#convert str to date
from datetime import datetime
new_dates = [datetime.strptime(date, '%Y-%m-%d') for date in new_dates]

# %%
X=np.array(X)

# %%
y=np.array(y)

# %%
X.shape,y.shape
# Out:
# ((1151, 52, 49, 7), (1151, 52, 49))

# %%
new_dates=np.array(new_dates)
index=np.argsort(new_dates)
X=X[index]
y=y[index]

# %%
#min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)
X.shape
# Out:
# (1151, 52, 49, 7)

# %%
y=scaler.fit_transform(y.reshape(-1, 1)).reshape(y.shape)
y.shape
# Out:
# (1151, 52, 49)

# %%
X.min(),X.max(),y.min(),y.max()
# Out:
# (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0))

# %% [markdown]
# windows

# %%
#forecasting window
def window(X,y,v):
  yt=y[v:]
  Xt=[]
  for i in range(X.shape[0]-v):
    Xt.append(X[i:i+v])

  return np.array(Xt),yt

# %%
Xt,yt=window(X,y,3)
Xt.shape,yt.shape
# Out:
# ((1148, 3, 52, 49, 7), (1148, 52, 49))

# %%
Xt.shape[1:]
# Out:
# (3, 52, 49, 7)

# %%
Xt.shape
# Out:
# (1148, 3, 52, 49, 7)

# %%
Xtrain=Xt[:int(0.8*Xt.shape[0])]
ytrain=yt[:int(0.8*yt.shape[0])]

Xtest=Xt[int(0.8*Xt.shape[0]):]
ytest=yt[int(0.8*yt.shape[0]):]

# %%
X_train=Xtrain[:int(0.8*Xtrain.shape[0])]
y_train=ytrain[:int(0.8*ytrain.shape[0])]

X_test=Xtrain[int(0.8*Xtrain.shape[0]):]
y_test=ytrain[int(0.8*ytrain.shape[0]):]

# %% [markdown]
# model

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ConvLSTM2D, Conv2D, BatchNormalization, Dropout

inputs = Input(shape=(Xt.shape[1:]))  # ventana temporal, alto, ancho, canales

x = ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False, activation='relu')(inputs)
x = BatchNormalization()(x)             # Normalización para estabilizar
x = Dropout(0.3)(x)                     # Dropout para evitar sobreajuste

x = Conv2D(filters=16, kernel_size=(3, 3), padding='same', activation='relu')(x)
x = BatchNormalization()(x)             # Otra capa de normalización
x = Dropout(0.3)(x)                     # Más dropout

outputs = Conv2D(filters=1, kernel_size=(3, 3), padding='same', activation='linear')(x)

model = Model(inputs, outputs)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 3, 52, 49, 7)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_lstm2d_1 (ConvLSTM2D)      │ (None, 52, 49, 32)     │        45,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 52, 49, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 52, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 49, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 52, 49, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 52, 49, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 52, 49, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,017 (195.38 KB)
#  Trainable params: 49,921 (195.00 KB)
#  Non-trainable params: 96 (384.00 B)

# %%
path="/content/drive/MyDrive/investigacion/windows"

# %%
#early stopping
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
#metrics
from tensorflow.keras.metrics import MeanAbsoluteError

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-8)
checkpoint= ModelCheckpoint(filepath=path+'model.keras', monitor='val_loss', save_best_only=True)

model.fit(Xtrain, ytrain, epochs=1000, batch_size=32,validation_data=(X_test,y_test), callbacks=[early_stopping, reduce_lr,checkpoint])
# Out:
# Epoch 1/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 305ms/step - loss: 1.1750 - mae: 0.7582 - val_loss: 0.0888 - val_mae: 0.2100 - learning_rate: 0.0010
# Epoch 2/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4926 - mae: 0.4875 - val_loss: 0.0860 - val_mae: 0.2362 - learning_rate: 0.0010
# Epoch 3/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.3225 - mae: 0.3959 - val_loss: 0.0861 - val_mae: 0.2410 - learning_rate: 0.0010
# Epoch 4/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2165 - mae: 0.3276 - val_loss: 0.0846 - val_mae: 0.2390 - learning_rate: 0.0010
# Epoch 5/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1465 - mae: 0.2722 - val_loss: 0.0829 - val_mae: 0.2351 - learning_rate: 0.0010
# Epoch 6/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0996 - mae: 0.2260 - val_loss: 0.0805 - val_mae: 0.2262 - learning_rate: 0.0010
# Epoch 7/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0683 - mae: 0.1886 - val_loss: 0.0773 - val_mae: 0.2156 - learning_rate: 0.0010
# Epoch 8/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0483 - mae: 0.1579 - val_loss: 0.0738 - val_mae: 0.2024 - learning_rate: 0.0010
# Epoch 9/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0344 - mae: 0.1327 - val_loss: 0.0702 - val_mae: 0.1900 - learning_rate: 0.0010
# Epoch 10/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0251 - mae: 0.1119 - val_loss: 0.0658 - val_mae: 0.1756 - learning_rate: 0.0010
# Epoch 11/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0199 - mae: 0.0966 - val_loss: 0.0611 - val_mae: 0.1590 - learning_rate: 0.0010
# Epoch 12/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0163 - mae: 0.0848 - val_loss: 0.0557 - val_mae: 0.1441 - learning_rate: 0.0010
# Epoch 13/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0141 - mae: 0.0764 - val_loss: 0.0508 - val_mae: 0.1313 - learning_rate: 0.0010
# Epoch 14/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0129 - mae: 0.0707 - val_loss: 0.0445 - val_mae: 0.1199 - learning_rate: 0.0010
# Epoch 15/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0121 - mae: 0.0667 - val_loss: 0.0401 - val_mae: 0.1071 - learning_rate: 0.0010
# Epoch 16/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0116 - mae: 0.0639 - val_loss: 0.0340 - val_mae: 0.0953 - learning_rate: 0.0010
# Epoch 17/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0110 - mae: 0.0617 - val_loss: 0.0285 - val_mae: 0.0851 - learning_rate: 0.0010
# Epoch 18/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0106 - mae: 0.0602 - val_loss: 0.0256 - val_mae: 0.0779 - learning_rate: 0.0010
# Epoch 19/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0102 - mae: 0.0588 - val_loss: 0.0183 - val_mae: 0.0720 - learning_rate: 0.0010
# Epoch 20/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0102 - mae: 0.0581 - val_loss: 0.0154 - val_mae: 0.0620 - learning_rate: 0.0010
# Epoch 21/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0099 - mae: 0.0572 - val_loss: 0.0125 - val_mae: 0.0535 - learning_rate: 0.0010
# Epoch 22/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0097 - mae: 0.0564 - val_loss: 0.0091 - val_mae: 0.0461 - learning_rate: 0.0010
# Epoch 23/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0096 - mae: 0.0557 - val_loss: 0.0082 - val_mae: 0.0418 - learning_rate: 0.0010
# Epoch 24/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0093 - mae: 0.0549 - val_loss: 0.0062 - val_mae: 0.0359 - learning_rate: 0.0010
# Epoch 25/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0092 - mae: 0.0544 - val_loss: 0.0056 - val_mae: 0.0323 - learning_rate: 0.0010
# Epoch 26/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0091 - mae: 0.0539 - val_loss: 0.0051 - val_mae: 0.0296 - learning_rate: 0.0010
# Epoch 27/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0091 - mae: 0.0536 - val_loss: 0.0046 - val_mae: 0.0261 - learning_rate: 0.0010
# Epoch 28/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0089 - mae: 0.0531 - val_loss: 0.0041 - val_mae: 0.0233 - learning_rate: 0.0010
# Epoch 29/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0087 - mae: 0.0524 - val_loss: 0.0042 - val_mae: 0.0238 - learning_rate: 0.0010
# Epoch 30/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0088 - mae: 0.0524 - val_loss: 0.0042 - val_mae: 0.0235 - learning_rate: 0.0010
# Epoch 31/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0087 - mae: 0.0518 - val_loss: 0.0039 - val_mae: 0.0220 - learning_rate: 0.0010
# Epoch 32/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0085 - mae: 0.0513 - val_loss: 0.0038 - val_mae: 0.0206 - learning_rate: 0.0010
# Epoch 33/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0084 - mae: 0.0509 - val_loss: 0.0039 - val_mae: 0.0224 - learning_rate: 0.0010
# Epoch 34/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0085 - mae: 0.0507 - val_loss: 0.0038 - val_mae: 0.0217 - learning_rate: 0.0010
# Epoch 35/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0083 - mae: 0.0504 - val_loss: 0.0037 - val_mae: 0.0204 - learning_rate: 0.0010
# Epoch 36/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0084 - mae: 0.0501 - val_loss: 0.0037 - val_mae: 0.0204 - learning_rate: 0.0010
# Epoch 37/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0081 - mae: 0.0496 - val_loss: 0.0036 - val_mae: 0.0202 - learning_rate: 0.0010
# Epoch 38/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0082 - mae: 0.0495 - val_loss: 0.0036 - val_mae: 0.0208 - learning_rate: 0.0010
# Epoch 39/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0081 - mae: 0.0494 - val_loss: 0.0036 - val_mae: 0.0199 - learning_rate: 0.0010
# Epoch 40/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0080 - mae: 0.0490 - val_loss: 0.0035 - val_mae: 0.0198 - learning_rate: 0.0010
# Epoch 41/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0079 - mae: 0.0486 - val_loss: 0.0035 - val_mae: 0.0197 - learning_rate: 0.0010
# Epoch 42/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0077 - mae: 0.0483 - val_loss: 0.0036 - val_mae: 0.0202 - learning_rate: 0.0010
# Epoch 43/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0078 - mae: 0.0483 - val_loss: 0.0034 - val_mae: 0.0194 - learning_rate: 0.0010
# Epoch 44/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0077 - mae: 0.0479 - val_loss: 0.0034 - val_mae: 0.0192 - learning_rate: 0.0010
# Epoch 45/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0076 - mae: 0.0477 - val_loss: 0.0034 - val_mae: 0.0187 - learning_rate: 0.0010
# Epoch 46/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0076 - mae: 0.0475 - val_loss: 0.0034 - val_mae: 0.0192 - learning_rate: 0.0010
# Epoch 47/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0076 - mae: 0.0475 - val_loss: 0.0033 - val_mae: 0.0186 - learning_rate: 0.0010
# Epoch 48/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0075 - mae: 0.0471 - val_loss: 0.0033 - val_mae: 0.0191 - learning_rate: 0.0010
# Epoch 49/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0075 - mae: 0.0470 - val_loss: 0.0032 - val_mae: 0.0186 - learning_rate: 0.0010
# Epoch 50/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0075 - mae: 0.0468 - val_loss: 0.0032 - val_mae: 0.0182 - learning_rate: 0.0010
# Epoch 51/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0073 - mae: 0.0466 - val_loss: 0.0032 - val_mae: 0.0183 - learning_rate: 0.0010
# Epoch 52/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0073 - mae: 0.0464 - val_loss: 0.0032 - val_mae: 0.0183 - learning_rate: 0.0010
# Epoch 53/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0072 - mae: 0.0461 - val_loss: 0.0032 - val_mae: 0.0188 - learning_rate: 0.0010
# Epoch 54/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0072 - mae: 0.0460 - val_loss: 0.0031 - val_mae: 0.0187 - learning_rate: 0.0010
# Epoch 55/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0071 - mae: 0.0457 - val_loss: 0.0031 - val_mae: 0.0188 - learning_rate: 0.0010
# Epoch 56/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0072 - mae: 0.0458 - val_loss: 0.0031 - val_mae: 0.0186 - learning_rate: 0.0010
# Epoch 57/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0072 - mae: 0.0456 - val_loss: 0.0032 - val_mae: 0.0203 - learning_rate: 0.0010
# Epoch 58/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0071 - mae: 0.0455 - val_loss: 0.0031 - val_mae: 0.0189 - learning_rate: 0.0010
# Epoch 59/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0070 - mae: 0.0453 - val_loss: 0.0031 - val_mae: 0.0181 - learning_rate: 0.0010
# Epoch 60/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0069 - mae: 0.0451 - val_loss: 0.0030 - val_mae: 0.0196 - learning_rate: 0.0010
# Epoch 61/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0070 - mae: 0.0451 - val_loss: 0.0031 - val_mae: 0.0192 - learning_rate: 0.0010
# Epoch 62/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0069 - mae: 0.0448 - val_loss: 0.0031 - val_mae: 0.0193 - learning_rate: 0.0010
# Epoch 63/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0069 - mae: 0.0447 - val_loss: 0.0031 - val_mae: 0.0191 - learning_rate: 0.0010
# Epoch 64/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0069 - mae: 0.0448 - val_loss: 0.0032 - val_mae: 0.0201 - learning_rate: 0.0010
# Epoch 65/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0068 - mae: 0.0445 - val_loss: 0.0030 - val_mae: 0.0187 - learning_rate: 0.0010
# Epoch 66/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0068 - mae: 0.0443 - val_loss: 0.0030 - val_mae: 0.0186 - learning_rate: 0.0010
# Epoch 67/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0068 - mae: 0.0441 - val_loss: 0.0032 - val_mae: 0.0216 - learning_rate: 0.0010
# Epoch 68/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - mae: 0.0442 - val_loss: 0.0031 - val_mae: 0.0196 - learning_rate: 0.0010
# Epoch 69/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0439 - val_loss: 0.0030 - val_mae: 0.0187 - learning_rate: 1.0000e-04
# Epoch 70/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0068 - mae: 0.0440 - val_loss: 0.0030 - val_mae: 0.0182 - learning_rate: 1.0000e-04
# Epoch 71/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - mae: 0.0440 - val_loss: 0.0029 - val_mae: 0.0180 - learning_rate: 1.0000e-04
# Epoch 72/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - mae: 0.0439 - val_loss: 0.0029 - val_mae: 0.0178 - learning_rate: 1.0000e-04
# Epoch 73/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0439 - val_loss: 0.0029 - val_mae: 0.0181 - learning_rate: 1.0000e-04
# Epoch 74/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0439 - val_loss: 0.0029 - val_mae: 0.0185 - learning_rate: 1.0000e-04
# Epoch 75/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0180 - learning_rate: 1.0000e-04
# Epoch 76/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0030 - val_mae: 0.0184 - learning_rate: 1.0000e-04
# Epoch 77/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0180 - learning_rate: 1.0000e-04
# Epoch 78/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0183 - learning_rate: 1.0000e-04
# Epoch 79/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0067 - mae: 0.0439 - val_loss: 0.0029 - val_mae: 0.0180 - learning_rate: 1.0000e-04
# Epoch 80/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0178 - learning_rate: 1.0000e-04
# Epoch 81/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0179 - learning_rate: 1.0000e-04
# Epoch 82/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0180 - learning_rate: 1.0000e-05
# Epoch 83/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 0.0066 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0180 - learning_rate: 1.0000e-05
# Epoch 84/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0181 - learning_rate: 1.0000e-05
# Epoch 85/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0067 - mae: 0.0439 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-05
# Epoch 86/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0181 - learning_rate: 1.0000e-05
# Epoch 87/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0181 - learning_rate: 1.0000e-05
# Epoch 88/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0183 - learning_rate: 1.0000e-05
# Epoch 89/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-05
# Epoch 90/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0436 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-05
# Epoch 91/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-05
# Epoch 92/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 93/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 94/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0066 - mae: 0.0436 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 95/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 96/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 97/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 98/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0067 - mae: 0.0438 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 99/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06
# Epoch 100/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0066 - mae: 0.0437 - val_loss: 0.0029 - val_mae: 0.0182 - learning_rate: 1.0000e-06

# %%
#plot history
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

# %%
model.evaluate(Xtest,ytest)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.0030 - mae: 0.0179
# [0.002964023733511567, 0.017785878852009773]

# %%
ytest.shape
# Out:
# (230, 52, 49)

# %%
#r2 score
from sklearn.metrics import r2_score
n=ytest.shape[0]
y_pred = model.predict(Xtest)
y_pred[ytest==0]=0
r2_score(ytest.reshape(n,-1), y_pred.reshape(n,-1))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step
# 0.5090985752100564

# %%
plt.subplot(1, 2, 1)
plt.title('Original')
plt.imshow(ytest[90])
plt.subplot(1, 2, 2)
plt.title('Predicted')
plt.imshow(y_pred[90])
plt.show()
